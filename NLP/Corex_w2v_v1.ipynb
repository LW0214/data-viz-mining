# %%
import numpy as np
import scipy.sparse as ss
import random
import pandas as pd

from corextopic import corextopic as ct
from corextopic import vis_topic as vt # jupyter notebooks will complain matplotlib is being loaded twice

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer

import pyLDAvis
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

import gensim
from sklearn.datasets import fetch_20newsgroups
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim.corpora import Dictionary

import os
import numpy as np
import pandas as pd
import pickle
import pyLDAvis
import pyLDAvis.gensim_models


from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/muruwu/opt/anaconda3/lib/python3.8/site-packages/gensim/corpora/dictionary.py:11: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Mapping, defaultdict
# /Users/muruwu/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /Users/muruwu/opt/anaconda3/lib/python3.8/site-packages/gensim/models/doc2vec.py:73: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import namedtuple, defaultdict, Iterable

# %%
import warnings
warnings.simplefilter('ignore')

# %%
#just for convenience of outputting all files to this specific project folder for this model
os.chdir('Amanda_model')

# %%
import matplotlib.pyplot as plt
def describe_training_documents(list_of_docs):
    print('There are',len(list_of_docs),'documents.')
    document_lengths = list(map(lambda x: len(x.split()),list_of_docs))
    percentile_50 = int(np.percentile(document_lengths,50))
    percentile_95 = int(np.percentile(document_lengths,95))
    print('95% of the documents are below:',percentile_95,'words.')
    plt.axvline(percentile_50, lw=1, color='g')
    plt.axvline(percentile_95, lw=1, color='r', linestyle='--')
    _ = plt.hist(document_lengths, bins=50, range=(0,percentile_95+100))
    print('Solid green line indicates median, dotted red line indicates 95 percentile. Outliers may be cropped.')

def flatten_list(l):
    return [item for sublist in l for item in sublist]

def tokenize(text):
    return [token for token in simple_preprocess(text) if token not in STOPWORDS]

def chop(text):
    temp=text.split()
    num=len(temp)//40
    new=[]
    for i in range(num):
        if i !=num-1:
            a=temp[30*i:30*(i+1)]
        else:
            a=temp[30*(num-1):]
        new.append(" ".join(a))
    return new

# %%
# Get 20 newsgroups data
newsgroups = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
documents_train = list(np.load('../../training/train.npy')) # historical materials 4451 documents
documents_train2 = list(np.load('../../training/train2.npy'))   # census bureau 4226 documents
df_occsc = pd.read_csv('../../OCC_pairs.csv').rename(columns={'OCC_DES':'Full Occupation'})
assert(df_occsc['Full Occupation'].nunique() == len(df_occsc))
occ_list = list(set(list(df_occsc['Full Occupation'])))

occ_list2=[]
#eliminate confusing words in the occ_list
confusing_words=['occupation','occupations','Occupations','men']
for occ in occ_list:
    a=occ.split(' ')
    for word in confusing_words:
        if word in a:
            a.remove(word)
    occ_list2.append(' '.join(a))  
occ_list=occ_list2

# %%
with open("../../training/nyt_text_modified.txt",'r') as f:
    nyt_text2=[]
    lines=f.readlines()
    for line in lines:
        nyt_text2.append(line)

# %% [markdown]
# # Q: why select only 4000

# %%
twenty_news=[]
for news in newsgroups.data:
    if len(news.split())>15:
        twenty_news.append(news)
describe_training_documents(twenty_news)
random.seed(10)
twenty_news=random.sample(twenty_news,4000)
# Out:
# There are 10372 documents.
# 95% of the documents are below: 605 words.
# Solid green line indicates median, dotted red line indicates 95 percentile. Outliers may be cropped.

# %%
# but fit the model with the training dataset
# corex model requires them to be the same shape 
documents = []
documents.extend(documents_train)
documents.extend(documents_train2)
documents.extend(nyt_text2)

documents_mod=[]
for doc in documents:
    chopped=chop(doc)
    for a in chopped:
        tokens=simple_preprocess(a)
        new_tokens=[]
        for word in tokens:
            if not word.isdigit():
                new_tokens.append(word)
        new=" ".join(new_tokens)
        documents_mod.append(new)

# %%
document_total=documents_mod[:]
document_total.extend(occ_list)
print(len(documents_mod))
print("In the dataset there are", len(document_total), "textual documents")
print("And this is the first one:\n", documents_mod[0])
# Out:
# 12522
# In the dataset there are 12958 textual documents
# And this is the first one:
#  skip to main content search upload sign up log in books video audio software imagesabout blog projects help donate contact jobs volunteer people search metadata search text contents search

# %% [markdown]
# ***
# below are merely test functions
# ***

# %% [markdown]
# # Q: but this isn't successfully parsed for some reason

# %%
len_arr=np.asarray([len(item.split(' ')) for item in document_total])
document_total[np.argmax(len_arr)]
# Out:
# 'come from great britain sad and painful chronicle though it is it is film that ends with flash of miss cavell grave and the suggestion of the shooting of miss cavell the actual scene has been excluded is another of the depressing incidents this picture begins with glimpses of miss cavell hospital in brussels the actual scenes are shown in some instances the exteriors having been filmed in the belgian capital some of it is done extraordinarily well although there are times when the settings appear to be cramped especially in those passages depicting the fugitives awaiting chance to steal away with the assistance of nurse cavell and mme bodard and mme rappard mr wilcox tells his gruesome story with proper suspense and he depicts adroitly the dread of discovery except for few instances he portrays the germans in sensible restrained fashion some of them being filled with sympathy for miss cavell but although this film holds the attention it is grim disheartening echo of the war and it should be remembered that miss cavell last words were patriotism is not enough must have no hatred or bitterness for any one in letter regarding this picture lord birkenhead wrote does any one suppose that the woman who at the very moment of her agony could speak like this referring to her last utterance would permit her death to be commercialized with the certain result that the bitter memories associated with it would be kept alive and fertilized so as to prevent the sweet restoration of friendship and good relationship between the nations of the world mechanical story with all its possibilities for picture herbert brenon has fashioned from laugh clewn laugh the play by david belasco and tom cushing nothing more than an unimaginative series of scenes which although some of them are effective units leave one cold it has neither heart nor soul and there are quite number of absurdly extravagant sequences in one episode the girl simonetta whom the clown tito beppi has rescued as waif hurts her leg the young waster count luigi ravelli discovers simonetta and filled with compassion for her evidently slight injury he carries her into his palatial house he does not stop in the drawing room or the library but goes all the way to his own room where after he has bandaged the injury he imprints kisses on simonetta pretty foot the dinner party in another scene is thoroughly moviesque affair but even such ideas would be pardonable if the action of the drama were more human the old old story of grimaldi comes forth as if it were thought by the producer to be something new and nils asther portrayal in one chapter of the giggling nobleman is by no means effective luigi through wine and women is supposed to be in highly nervous condition and tito played by lon chaney has lost his grip on life so that he sobs they the laughing count and the tearful clown go to the same nerve specialist and both are recommended the same prescription wholesome love simonetta so it happens is the girl with whom the young nobleman and the middle aged clown are infatuated rajah menjou little levity fell on broadway last week in the shape of the tiger lady wherein the dependable adolphe menjou plays an exceedingly amusing part that of stage super named henri who falls head over heels in love with the imperious creature who reigns over the show the background is paris and the story is farcical but nevertheless quite intriguing it has moments that are delightful especially an episode where this super arrayed in his glittering rajah stage costume invades restaurant with all the aplomb of an eastern potentate he must have certain table because it is near the one at which are seated the tiger lady and her entourage of duke marquis and count and insists that regular patron of the restaurant now busy refreshing the inner man shall resign in favor of himself once the man has been prevailed upon to move henri looking like the wealthiest of rajahs languidly takes his place he is pale hindu but that ...

# %% [markdown]
# # Q: And there're documents with non-English chars
# we can clean with basic regrex maybe

# %%
print(max(document_total))
# Out:
# 穏raphic division the proportion was higher for the foreignborn white mafos than for the males of either of the nath積 white classes and in ach of the geographic dhisions except

# %%
plt.figure(0)
plt.plot(len_arr)
plt.xlabel('doc_number')
plt.ylabel('doc_length')
# Out:
# Text(0, 0.5, 'doc_length')

# %% [markdown]
# ***
# test codes end
# ***

# %% [markdown]
# ## Transform data into a sparse matrix¶

# %% [markdown]
# # count vectorizer
# (filtering out: useless phrases like 'aa','ab' with token_pattern, & min_df)

# %%
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=2,
# minimum reqd occurences of a word 
                             stop_words='english',             
# remove stop words
                             lowercase=True,                   
# convert all words to lowercase
                             token_pattern='[a-zA-Z]{3,}',  
# num chars > 3
                             max_features=20000,             
# max number of uniq words    
                            )
data_vectorized = vectorizer.fit_transform(document_total)

# %%
doc_word = vectorizer.fit_transform(document_total)
doc_word = ss.csr_matrix(doc_word)
fixed_vocabulary=vectorizer.vocabulary_
words = list(np.asarray(vectorizer.get_feature_names()))

# %% [markdown]
# # Q: try find frequency of fixed voc

# %%
fixed_vocabulary
# Out:
# {'skip': 11855,
#  'main': 7750,
#  'content': 2762,
#  'search': 11406,
#  'upload': 13729,
#  'sign': 11753,
#  'log': 7582,
#  'books': 1385,
#  'video': 13910,
#  'audio': 873,
#  'software': 11979,
#  'imagesabout': 6376,
#  'blog': 1316,
#  'projects': 10083,
#  'help': 6058,
#  'donate': 3848,
#  'contact': 2745,
#  'jobs': 7009,
#  'volunteer': 13987,
#  'people': 9361,
#  'metadata': 8089,
#  'text': 12955,
#  'contents': 2765,
#  'news': 8588,
#  'captions': 1803,
#  'radio': 10346,
#  'transcripts': 13320,
#  'archived': 652,
#  'searchsign': 11408,
#  'freelog': 5316,
#  'infull': 6657,
#  'practical': 9830,
#  'cabinet': 1693,
#  'maker': 7768,
#  'furniture': 5416,
#  'designer': 3484,
#  'assistant': 782,
#  'essays': 4478,
#  'history': 6136,
#  'taste': 12822,
#  'design': 3478,
#  'color': 2397,
#  'materials': 7928,
#  'explanation': 4682,
#  'canons': 1770,
#  'good': 5657,
#  'formats': 5225,
#  'preparing': 9895,
#  'work': 14339,
#  'think': 13016,
#  'unnecessary': 13676,
#  'waste': 14083,
#  'time': 13128,
#  'space': 12057,
#  'publishing': 10193,
#  'preface': 9874,
#  'occupy': 8793,
#  'pages': 9124,
#  'best': 1216,
#  'little': 7532,
#  'service': 11542,
#  'readers': 10434,
#  'serve': 11539,
#  'better': 1219,
#  'inserting': 6719,
#  'remarks': 10680,
#  'gist': 5586,
#  'expected': 4647,
#  'appear': 569,
#  'material': 7925,
#  'interesting': 6804,
#  'useful': 13754,
#  'old': 8850,
#  'times': 13130,
#  'man': 7789,
#  'hold': 6161,
#  'head': 5998,
#  'say': 11294,
#  'truthfully': 13452,
#  'cabinetmaker': 1694,
#  'meant': 7983,
#  'given': 5587,
#  'long': 7594,
#  'years': 14428,
#  'apprenticeship': 607,
#  'branch': 1465,
#  'business': 1665,
#  'assertion': 769,
#  'interpreted': 6822,
#  'timber': 13127,
#  'saw': 11285,
#  'plane': 9594,
#  'mould': 8372,
#  'glue': 5628,
#  'veneer': 13850,
#  'join': 7019,
#  'carve': 1868,
#  'finish': 5008,
#  'upholster': 13722,
#  'hand': 5896,
#  'knowledge': 7169,
#  'connected': 2656,
#  'manufacture': 7833,
#  'entrance': 4402,
#  'yard': 14419,
#  'wareroom': 14053,
#  'workmen': 14351,
#  'way': 14106,
#  'completeness': 2527,
#  'invention': 6860,
#  'disarranged': 3645,
#  'certainly': 1980,
#  'labor': 7187,
#  'saving': 11281,
#  'machinery': 7719,
#  'later': 7267,
#  'dispensed': 3720,
#  'necessity': 8525,
#  'circular': 2172,
#  'saws': 11292,
#  'jig': 7002,
#  'band': 993,
#  'stickers': 12321,
#  'planers': 9596,
#  'jointers': 7027,
#  'carvers': 1871,
#  'contrivances': 2804,
#  'economizing': 4089,
#  'terms': 12932,
#  'measure': 7988,
#  'day': 3227,
#  'men': 8046,
#  'makers': 7769,
#  'sense': 11500,
#  'referred': 10558,
#  'competent': 2513,
#  'sawing': 11288,
#  'moulding': 8374,
#  'planing': 9598,
#  'subdivision': 12486,
#  'outgrowth': 9035,
#  'advance': 213,
#  'applicants': 587,
#  'belong': 1166,
#  'classes': 2212,
#  'representatives': 10766,
#  'school': 11334,
#  'fledgelings': 5080,
#  'having': 5987,
#  'rubbed': 11123,
#  'months': 8308,
#  'manufactory': 7831,
#  'consider': 2685,
#  'fit': 5039,
#  'subjects': 12491,
#  'diploma': 3614,
#  'advantageous': 219,
#  'mix': 8228,
#  'elements': 4182,
#  'claims': 2198,
#  'worthy': 14372,
#  'consideration': 2688,
#  'class': 2210,
#  'drilled': 3939,
#  'faithfully': 4790,
#  'department': 3424,
#  'apt': 628,
#  'wedded': 14136,
#  'firmly': 5028,
#  'methods': 8099,
#  'use': 13750,
#  'apprentices': 606,
#  'kind': 7127,
#  'progressive': 10074,
#  'restless': 10858,
#  'restraint': 10863,
#  'average': 910,
#  'bench': 1176,
#  'hands': 5911,
#  'bear': 1094,
#  'mind': 8165,
#  'experience': 4664,
#  'quality': 10276,
#  'extended': 4715,
#  'require': 10789,
#  'cases': 1877,
#  'machine': 7717,
#  'manufacturer': 7835,
#  'readily': 10435,
#  'perceive': 9366,
#  'advantage': 218,
#  'engage': 4323,
#  'services': 11544,
#  'confined': 2626,
#  'exclusively': 4598,
#  'pledge': 9648,
#  'run': 11151,
#  'migratory': 8133,
#  'curse': 3124,
#  'examples': 4566,
#  'saying': 11295,
#  'rolling': 11062,
#  'stone': 12360,
#  'gathers': 5484,
#  'moss': 8355,
#  'includes': 6496,
#  'individual': 6575,
#  'workman': 14348,
#  'intelligent': 6785,
#  'admirable': 187,
#  'making': 7773,
#  'exact': 4552,
#  'reproducing': 10775,
#  'agent': 279,
#  'consequently': 2679,
#  'aiding': 319,
#  'uniform': 13634,
#  'results': 10873,
#  'questioned': 10304,
#  'plan': 9593,
#  'make': 7767,
#  'machines': 7720,
#  'possible': 9777,
#  'excellence': 4574,
#  'sacrificed': 11181,
#  'tolerable': 13210,
#  'uniformity': 13635,
#  'mechanics': 8000,
#  'ago': 296,
#  'sympathy': 12728,
#  'lowers': 7654,
#  'status': 12272,
#  'mechanical': 7998,
#  'conditions': 2602,
#  'level': 7399,
#  'attendant': 847,
#  'monotonous': 8297,
#  'worker': 14342,
#  'single': 11803,
#  'job': 7005,
#  'shop': 11691,
#  'reasonable': 10460,
#  'embryo': 4234,
#  'mechanic': 7997,
#  'desire': 3490,
#  'foreman': 5198,
#  'known': 7170,
#  'establishments': 4492,
#  'country': 2961,
#  'recently': 10488,
#  'died': 3567,
#  'conversation': 2822,
#  'stated': 12247,
#  'intimate': 6836,
#  'different': 3577,
#  'departments': 3426,
#  'got': 5673,
#  'chance': 2010,
#  'lathe': 7270,
#  'carving': 1872,
#  'room': 11075,
#  'drawings': 3915,
#  'sketches': 11841,
#  'frequently': 5329,
#  'designs': 3487,
#  'accomplishments': 73,
#  'crude': 3065,
#  'gave': 5491,
#  'idea': 6323,
#  'accomplished': 70,
#  'example': 4565,
#  'sort': 12026,
#  'grand': 5711,
#  'art': 720,
#  'movement': 8389,
#  'victor': 13906,
#  'hugo': 6271,
#  'notre': 8693,
#  'dame': 3184,
#  'paris': 9201,
#  'brilliant': 1518,
#  'expression': 4708,
#  'objects': 8752,
#  'gradually': 5697,
#  'developed': 3530,
#  'intensity': 6794,
#  'incredible': 6527,
#  'stuffs': 12467,
#  'china': 2116,
#  'ware': 14050,
#  'preceding': 9854,
#  'centuries': 1970,
#  'battered': 1074,
#  'sold': 11985,
#  'prices': 9958,
#  'far': 4817,
#  'higher': 6111,
#  'construction': 2724,
#  'tendency': 12903,
#  'wrong': 14396,
#  'fashion': 4833,
#  'mania': 7803,
#  'exaggeration': 4557,
#  'based': 1051,
#  'fantasy': 4816,
#  'imitation': 6389,
#  'nation': 8482,
#  'great': 5747,
#  'nations': 8490,
#  'world': 14358,
#  'possibly': 9778,
#  'deceived': 3266,
#  'extent': 4721,
#  'unanimity': 13559,
#  'solid': 11994,
#  'basis': 1059,
#  'antique': 535,
#  'does': 3825,
#  'rest': 10852,
#  'logical': 7588,
#  'foundation': 5256,
#  'disdain': 3688,
#  'phantom': 9462,
#  'perfecting': 9377,
#  'wood': 14318,
#  'working': 14344,
#  'arrived': 716,
#  'degrees': 3350,
#  'scarcely': 11309,
#  'presenting': 9906,
#  'slightest': 11893,
#  'degree': 3349,
#  'solidity': 11997,
#  'mahogany': 7744,
#  'oak': 8739,
#  'walnut': 14036,
#  'rose': 11087,
#  'coated': 2336,
#  'cracking': 2991,
#  'shock': 11679,
#  'peeling': 9331,
#  'change': 2016,
#  'dampness': 3192,
#  'dryness': 3966,
#  'weather': 14128,
#  'knows': 7171,
#  'equally': 4435,
#  'homely': 6183,
#  'thirty': 13035,
#  'queen': 10295,
#  'anne': 505,
#  'eastlake': 4066,
#  'inelegant': 6616,
#  'appearance': 570,
#  'uncomfortable': 13574,
#  'purchasing': 10223,
#  'just': 7074,
#  'procuring': 10026,
#  'articles': 725,
#  'altogether': 402,
#  'solidly': 11998,
#  'built': 1614,
#  'form': 5221,
#  'absolutely': 30,
#  'conformable': 2633,
#  'rules': 11146,
#  'entirely': 4396,
#  'nature': 8499,
#  'subject': 12488,
#  'limited': 7474,
#  'number': 8716,
#  'combinations': 2414,
#  'furnish': 5410,
#  'architects': 648,
#  'designers': 3485,
#  'resources': 10836,
#  'longing': 7597,
#  'escape': 4465,
#  'cold': 2366,
#  'generation': 5509,
#  'added': 144,
#  'renaissance': 10704,
#  'year': 14425,
#  'caused': 1916,
#  'greedy': 5755,
#  'demand': 3384,
#  'suddenly': 12540,
#  'arise': 667,
#  'arti': 722,
#  'introduction': 6849,
#  'changing': 2020,
#  'character': 2029,
#  'proved': 10159,
#  'boon': 1387,
#  'humanity': 6280,
#  'generally': 5505,
#  'masses': 7909,
#  'enjoyed': 4351,
#  'cheaper': 2073,
#  'productions': 10039,
#  'aid': 315,
#  'power': 9820,
#  'wish': 14285,
#  'impression': 6444,
#  'beauty': 1109,
#  'majority': 7766,
#  'graceful': 5692,
#  'adapted': 141,
#  'days': 3230,
#  'executed': 4602,
#  'fact': 4759,
#  'belief': 1156,
#  'woodworking': 14326,
#  'blessing': 1303,
#  'producer': 10033,
#  'user': 13757,
#  'fatal': 4844,
#  'distinctive': 3764,
#  'artistic': 730,
#  'handmade': 5909,
#  'object': 8747,
#  'writer': 14390,
#  'book': 1378,
#  'young': 14455,
#  'obtaining': 8772,
#  'enable': 4267,
#  'rough': 11100,
#  'reaches': 10427,
#  'finished': 5009,
#  'state': 12246,
#  'ready': 10441,
#  'place': 9579,
#  'intended': 6789,
#  'purpose': 10239,
#  'considered': 2690,
#  'finest': 5004,
#  'absorb': 31,
#  'inspiration': 6735,
#  'charm': 2051,
#  'said': 11199,
#  'justice': 7075,
#  'persuaded': 9437,
#  'condition': 2599,
#  'occasioned': 8781,
#  'market': 7870,
#  'high': 6110,
#  'demanded': 3385,
#  'owners': 9094,
#  'placed': 9580,
#  'dealers': 3239,
#  'actual': 130,
#  'cost': 2924,
#  'original': 8980,
#  'bought': 1423,
#  'rich': 10956,
#  'normal': 8658,
#  'middle': 8123,
#  'whos': 14212,
#  'equal': 4432,
#  'superior': 12611,
#  'indulge': 6588,
#  'larger': 7253,
#  'bright': 1512,
#  'sharp': 11617,
#  'hundreds': 6287,
#  'factories': 4762,
#  'trained': 13309,
#  'lumber': 7678,
#  'yards': 14421,
#  'running': 11155,
#  'delicate': 3370,
#  'study': 12461,
#  'soon': 12020,
#  'able': 10,
#  'fine': 4997,
#  'pieces': 9523,
#  'advanced': 214,
#  'students': 12454,
#  'hours': 6246,
#  'holidays': 6170,
#  'writing': 14393,
#  'splendid': 12135,
#  'board': 1333,
#  'newark': 8576,
#  'serving': 11546,
#  'city': 2187,
#  'apprentice': 605,
#  'shed': 11628,
#  'rear': 10457,
#  'house': 6247,
#  'polishing': 9703,
#  'sideboard': 11740,
#  'father': 4847,
#  'wealthy': 14122,
#  'neighbor': 8553,
#  'seeing': 11450,
#  'quite': 10323,
#  'completed': 2525,
#  'offered': 8818,
#  'buy': 1681,
#  'sum': 12583,
#  'including': 6497,
#  'mirrors': 8193,
#  'stained': 12205,
#  'leaded': 7311,
#  'glass': 5600,
#  'hardware': 5942,
#  'stuff': 12463,
#  'told': 13208,
#  'nearly': 8513,
#  'fifteenth': 4947,
#  'october': 8805,
#  'end': 4288,
#  'april': 624,
#  'comfortable': 2429,
#  'addition': 148,
#  'slender': 11881,
#  'yearly': 14426,
#  'salary': 11213,
#  'money': 8290,
#  'gained': 5434,
#  'fraction': 5279,
#  'benefit': 1185,
#  'derived': 3463,
#  'obtained': 8771,
#  'worth': 14370,
#  'received': 10482,
#  'course': 2970,
#  'large': 7251,
#  'percentage': 9370,
#  'purchasers': 10221,
#  'student': 12453,
#  'ornamental': 8993,
#  'cash': 1878,
#  'value': 13799,
#  'opening': 8906,
#  'cultivation': 3092,
#  'broader': 1539,
#  'modern': 8253,
#  'styles': 12479,
#  'chipendale': 2120,
#  'shereton': 11649,
#  'adams': 138,
#  'colonial': 2394,
#  'essential': 4479,
#  'aspires': 758,
#  'know': 7167,
#  'cultivate': 3090,
#  'conversant': 2821,
#  'various': 13820,
#  'glance': 5597,
#  'tell': 12879,
#  'style': 12477,
#  'lines': 7486,
#  'piece': 9521,
#  'represent': 10762,
#  'connection': 2659,
#  'proposed': 10124,
#  'lay': 7300,
#  'chapter': 2027,
#  'illustrations': 6373,
#  'explanations': 4683,
#  'details': 3513,
#  'offer': 8817,
#  'instructions': 6758,
#  'performing': 9386,
#  'gilding': 5573,
#  'staining': 12206,
#  'finishing': 5012,
#  'complete': 2524,
#  'available': 904,
#  'american': 431,
#  'reader': 10433,
#  'french': 5325,
#  'german': 5540,
#  'italian': 6939,
#  'renderings': 10708,
#  'english': 4338,
#  'try': 13454,
#  'cull': 3085,
#  'deem': 3312,
#  'suitable': 12569,
#  'cullings': 3086,
#  'works': 14354,
#  'consist': 2694,
#  'representing': 10768,
#  'masters': 7913,
#  'necessary': 8520,
#  'real': 10442,
#  'companion': 2487,
#  'stokes': 12356,
#  'published': 10190,
#  'henry': 6077,
#  'carey': 1835,
#  'baird': 965,
#  'philadelphia': 9467,
#  'excellent': 4575,
#  'contains': 2750,
#  'ceipts': 1934,
#  'dyeing': 4023,
#  'matter': 7939,
#  'alvan': 407,
#  'crocker': 3047,
#  'nye': 8736,
#  'deals': 3242,
#  'constructional': 2725,
#  'principle': 9979,
#  'regarding': 10591,
#  'historical': 6134,
#  'peculiarities': 9319,
#  'comstock': 2562,
#  'new': 8575,
#  'york': 14453,
#  'dated': 3216,
#  'manuals': 7825,
#  'written': 14395,
#  'chiefly': 2106,
#  'boys': 1449,
#  'intend': 6788,
#  'life': 7444,
#  'suited': 12570,
#  'amateur': 413,
#  'workers': 14343,
#  'intending': 6790,
#  'follow': 5147,
#  'living': 7542,
#  'prove': 10158,
#  'intends': 6791,
#  'professionally': 10054,
#  'journals': 7043,
#  'magazines': 7735,
#  'academic': 44,
#  'exceptions': 4583,
#  'reference': 10555,
#  'woodwork': 14325,
#  'genesis': 5514,
#  'noah': 8625,
#  'ark': 676,
#  'gopher': 5664,
#  'window': 14258,
#  'pitch': 9567,
#  'observe': 8761,
#  'definite': 3339,
#  'measurements': 7991,
#  'specific': 12088,
#  'directions': 3624,
#  'handed': 5898,
#  'gather': 5481,
#  'mankind': 7814,
#  'acquired': 111,
#  'early': 4039,
#  'period': 9391,
#  'kinds': 7132,
#  'tools': 13233,
#  'bas': 1048,
#  'reliefs': 10656,
#  'papyri': 9182,
#  'museums': 8433,
#  'egyptians': 4140,
#  'arts': 732,
#  'civilization': 2192,
#  'luxurious': 7698,
#  'evident': 4543,
#  'hebrews': 6041,
#  'teachers': 12847,
#  'taskmasters': 12820,
#  'enabled': 4268,
#  'acquire': 110,
#  'sufficient': 12554,
#  'skill': 11846,
#  'carry': 1862,
#  'precise': 9859,
#  'building': 1611,
#  'erection': 4448,
#  'tabernacle': 12739,
#  'christ': 2142,
#  'ornaments': 8998,
#  'fastenings': 4841,
#  'loops': 7612,
#  'taches': 12750,
#  'curtains': 3128,
#  'linen': 7484,
#  'coverings': 2980,
#  'dried': 3936,
#  'skins': 11854,
#  'turn': 13485,
#  'moment': 8279,
#  'exodus': 4636,
#  'convinced': 2841,
#  'mentioned': 8055,
#  'considerable': 2686,
#  'carrying': 1863,
#  'resulted': 10871,
#  'generations': 5510,
#  'carpenters': 1848,
#  'joiners': 7021,
#  'weavers': 14130,
#  'dyers': 4024,
#  'goldsmiths': 5649,
#  'craftsmen': 2997,
#  'thousand': 13059,
#  'descriptions': 3470,
#  'fitting': 5043,
#  'solomon': 11999,
#  'glorious': 5621,
#  'reign': 10621,
#  'temple': 12892,
#  'king': 7133,
#  'gathered': 5482,
#  'countries': 2960,
#  'skilful': 11843,
#  'artificers': 726,
#  'event': 4535,
#  'marks': 7876,
#  'era': 4442,
#  'brought': 1568,
#  'scheme': 11323,
#  'referring': 10559,
#  'testament': 12947,
#  'information': 6651,
#  'bearing': 1097,
#  'notice': 8684,
#  'approximate': 620,
#  'dates': 3217,
#  'accepted': 52,
#  'particular': 9225,
#  'importance': 6427,
#  'attached': 830,
#  'chronology': 2153,
#  'events': 4536,
#  'concerned': 2579,
#  'speaking': 12076,
#  'landmarks': 7237,
#  'verse': 13881,
#  'kings': 7135,
#  'chap': 2023,
#  'tells': 12881,
#  'chamber': 2002,
#  'wall': 14032,
#  'elisha': 4199,
#  'visited': 13948,
#  'shunamite': 11732,
#  'preparations': 9892,
#  'reception': 10491,
#  'prophet': 10112,
#  'let': 7395,
#  'set': 11551,
#  'bed': 1112,
#  'table': 12740,
#  'stool': 12364,
#  'candlestick': 1761,
#  'incident': 6481,
#  'allusion': 383,
#  'grandeur': 5712,
#  'palace': 9143,
#  'ahasuerus': 311,
#  'catch': 1903,
#  'glimpse': 5612,
#  'eastern': 4065,
#  'magnificence': 7741,
#  'description': 3469,
#  'drapery': 3904,
#  'furnished': 5411,
#  'apartment': 549,
#  'white': 14196,
#  'green': 5758,
#  'blue': 1328,
#  'hangings': 5919,
#  'fastened': 4839,
#  'cords': 2879,
#  'purple': 10235,
#  'silver': 11773,
#  'rings': 10990,
#  'pillars': 9543,
#  'marble': 7852,
#  'beds': 1117,
#  'gold': 5645,
#  'pavement': 9288,
#  'red': 10538,
#  'black': 1277,
#  'esther': 4498,
#  'unfortunately': 13627,
#  'trustworthy': 13450,
#  'ancient': 471,
#  'hebrew': 6040,
#  'kitto': 7146,
#  'bible': 1230,
#  'soltau': 12000,
#  'priesthood': 9964,
#  'offerings': 8820,
#  'similar': 11779,
#  'apparently': 563,
#  'drawn': 3916,
#  'imagination': 6378,
#  'founded': 5258,
#  'shew': 11653,
#  'bread': 1476,
#  'represented': 10767,
#  'legs': 7363,
#  'partly': 9231,
#  'turned': 13486,
#  'upper': 13730,
#  'portions': 9750,
#  'square': 12181,
#  'poles': 9692,
#  'carried': 1856,
#  'nomadic': 8640,
#  'primitive': 9971,
#  'jews': 7000,
#  'assyrians': 806,
#  'came': 1736,
#  'stock': 12351,
#  'spoke': 12144,
#  'language': 7242,
#  'exception': 4580,
#  'representations': 10764,
#  'figures': 4962,
#  'animals': 499,
#  'litchfield': 7520,
#  'says': 11296,
#  'mean': 7977,
#  'authority': 888,
#  'heads': 6009,
#  'stones': 12361,
#  'pillows': 9544,
#  'common': 2470,
#  'late': 7265,
#  'historic': 6133,
#  'chairs': 1998,
#  'tables': 12741,
#  'highly': 6113,
#  'wrought': 14400,
#  'ornamented': 8996,
#  'shown': 11720,
#  'monuments': 8313,
#  'come': 2421,
#  'possess': 9768,
#  'fragments': 5284,
#  'bronze': 1552,
#  'egyptian': 4139,
#  'assyrian': 805,
#  'thrones': 13088,
#  'illustrated': 6369,
#  'figs': 4958,
#  'fig': 4952,
#  'occupied': 8791,
#  'chair': 1990,
#  'feet': 4889,
#  'designed': 3483,
#  'limbs': 7467,
#  'stools': 12365,
#  'sitting': 11821,
#  'blocks': 1315,
#  'hollowed': 6175,
#  'couch': 2943,
#  'straight': 12384,
#  'lined': 7483,
#  'body': 1346,
#  'curved': 3134,
#  'like': 7460,
#  'ordinary': 8957,
#  'sofa': 11971,
#  'salient': 11220,
#  'points': 9685,
#  'carved': 1869,
#  'tails': 12766,
#  'boxes': 1444,
#  'coffers': 2353,
#  'gable': 5426,
#  'tops': 13238,
#  'dovetailed': 3874,
#  'small': 11912,
#  'toilet': 13202,
#  'painted': 9134,
#  'decoration': 3296,
#  'mummy': 8414,
#  'cedar': 1930,
#  'elaborate': 4150,
#  'hieroglyphic': 6109,
#  'decorations': 3297,
#  'seen': 11456,
#  'british': 1532,
#  'museum': 8432,
#  'louvre': 7641,
#  'chariot': 2040,
#  'horse': 6222,
#  'scarce': 11308,
#  'assyria': 804,
#  'practically': 9831,
#  'non': 8647,
#  'existent': 4632,
#  'climate': 2265,
#  'dry': 3964,
#  'preservative': 9909,
#  'egypt': 4138,
#  'thathave': 12967,
#  'wilfully': 14239,
#  'destroyed': 3506,
#  'perished': 9398,
#  'ivory': 6954,
#  'discovered': 3672,
#  'used': 13752,
#  'mountings': 8382,
#  'ends': 4305,
#  'seats': 11419,
#  'enables': 4269,
#  'fairly': 4783,
#  'accurate': 87,
#  'judgment': 7055,
#  'heavier': 6035,
#  'coarser': 2329,
#  'elegant': 4179,
#  'forms': 5231,
#  'parts': 9234,
#  'oriental': 8978,
#  'human': 6278,
#  'figure': 4960,
#  'representation': 10763,
#  'slaves': 11873,
#  'conquered': 2662,
#  'peoples': 9362,
#  'degraded': 3348,
#  'position': 9763,
#  'weight': 14150,
#  'seat': 11416,
#  'throne': 13087,
#  'monarch': 8284,
#  'captives': 1805,
#  'tied': 13107,
#  'doubtless': 3869,
#  'lions': 7500,
#  'arm': 679,
#  'supports': 12635,
#  'steps': 12308,
#  'antiquity': 536,
#  'principal': 9977,
#  'woods': 14323,
#  'ebony': 4076,
#  'rosewood': 11091,
#  'pine': 9550,
#  'teak': 12851,
#  'cedarwood': 1931,
#  'electrum': 4175,
#  'inlays': 6695,
#  'chariots': 2041,
#  'greeks': 5757,
#  'simply': 11792,
#  'copied': 2863,
#  'asiatic': 747,
#  'sources': 12042,
#  'animal': 498,
#  'plant': 9604,
#  'decorative': 3298,
#  'folding': 5141,
#  'metal': 8090,
#  'backs': 952,
#  'upright': 13731,
#  'greek': 5756,
#  'periods': 9395,
#  'inlaid': 6690,
#  'tripods': 13413,
#  'shapes': 11610,
#  'leopards': 7385,
#  'sphinxes': 12118,
#  'roman': 11066,
#  'grecian': 5753,
#  'ones': 8879,
#  'polished': 9699,
#  'face': 4751,
#  'cistae': 2179,
#  'cylindrical': 3163,
#  'rested': 10855,
#  'lid': 7433,
#  'cover': 2977,
#  'handle': 5905,
#  'knot': 7165,
#  'usually': 13765,
#  'surface': 12647,
#  'covered': 2978,
#  'engraved': 4342,
#  'compositions': 2542,
#  'borders': 1398,
#  'probably': 10007,
#  'contain': 2746,
#  'jewelry': 6997,
#  'romans': 11069,
#  'prized': 10001,
#  'paid': 9126,
#  'sums': 12595,
#  'pollard': 9709,
#  'cross': 3052,
#  'grain': 5704,
#  'hard': 5931,
#  'knots': 7166,
#  'showed': 11716,
#  'claws': 2231,
#  'boxwood': 1446,
#  'beech': 1121,
#  'palm': 9152,
#  'precious': 9858,
#  ...}

# %%
topic_num=60
topic_model = ct.Corex(n_hidden=topic_num, words=words, eps=1e-2,max_iter=100, verbose=False, seed=1)
topic_model.fit(doc_word[:len(documents_mod)], words=words)
# Out:
# /Users/muruwu/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING: Some words never appear (or always appear)

# %%
# Print a single topic from CorEx topic model
topic_model.get_topics(topic=20, n_words=10)
# Out:
# /Users/muruwu/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [('court', 0.03393634232279213, 1.0),
#  ('supreme', 0.013724482043672546, 1.0),
#  ('church', 0.013590422650932441, 1.0),
#  ('mrs', 0.01226573475648775, 1.0),
#  ('justice', 0.007554550292198364, 1.0),
#  ('trial', 0.0073437464182978165, 1.0),
#  ('rome', 0.006506363801370377, 1.0),
#  ('judge', 0.005825537721284398, 1.0),
#  ('london', 0.005527883561060897, 1.0),
#  ('teachers', 0.005435781149509974, 1.0)]

# %% [markdown]
# I aded '~' here since the original function also prints out words whose absence is significant to a topic (they have s<0), so here, I added ~ before them to distinguish these absent words from the other topic words
#
# For details, you can check here: https://github.com/gregversteeg/corex_topic#running-the-corex-topic-model

# %%
# Print all topics from the CorEx topic model

topics = topic_model.get_topics()
for n,topic in enumerate(topics):
    # w: word, mi: mutual information, s: sign
    topic_words,_,_ = zip(*[(w,mi,s) if s > 0 else ('~'+w,mi,s) for w,mi,s in topic])
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: water,inch,mold,sides,dry,cut,surface,cement,add,glue
# 1: products,establishments,value,total,cent,industry,reported,statistics,manufacture,increase
# 2: furniture,fig,chairs,design,art,seat,carved,decoration,pieces,designs
# 3: union,local,members,international,organization,locals,convention,executive,organized,employers
# 4: mills,goods,horsepower,power,production,quantity,steel,electric,rolling,primary
# 5: earners,wage,number,average,employed,prevailing,employees,salaried,employment,gives
# 6: president,yesterday,today,committee,washington,government,association,dec,congress,afternoon
# 7: age,proportion,table,females,according,males,gainful,classification,sex,census
# 8: states,united,pennsylvania,state,ohio,illinois,ranked,jersey,individual,north
# 9: gender,game,miss,match,volunteer,feminine,florid,search,sign,shooting
# 10: precinct,assignments,patrolmen,polish,duty,dye,annum,veneer,roman,temporary
# 11: university,technology,institute,cambridge,examinations,college,professor,oxford,yale,mother
# 12: market,exchange,posted,bills,rates,cable,sterling,packages,commercial,transfers
# 13: vegetables,washed,fruits,pan,cold,cooked,executed,heat,minutes,fruit
# 14: new,york,district,city,central,south,east,west,metropolitan,cities
# 15: turpentine,oak,rosin,woods,sulphuric,nitric,acids,chestnut,pine,brass
# 16: ivory,purport,ebony,depreciation,avoid,expensesas,twine,disclosure,facts,determining
# 17: milk,lesson,teacher,butter,cooking,foods,cheese,food,lessons,condensed
# 18: father,gen,guilty,speech,competent,sympathy,understanding,german,injury,screen
# 19: mix,pint,color,yellow,dissolve,colors,vinegar,powdered,stitch,ounces
# 20: court,supreme,church,mrs,justice,trial,rome,judge,london,teachers
# 21: wood,used,method,obtained,oil,varnish,finishing,described,woolen,grain
# 22: occupied,gainfully,animal,forestry,husbandry,agriculture,japanese,whites,parentage,native
# 23: month,representative,december,day,nearest,maximum,minimum,july,months,january
# 24: mind,borne,status,occupational,compare,estimate,industrytable,necessary,order,considering
# 25: street,kindred,american,exhibition,avenue,national,public,jan,john,seventh
# 26: people,spirit,health,workman,capable,novelty,really,ladies,enterprise,success
# 27: division,atlantic,service,newspapers,circulation,education,schools,mountain,publications,pacific
# 28: play,science,film,religion,picture,scenes,civilization,literature,boy,grave
# 29: week,hours,labor,trade,working,conditions,wages,worker,earnings,employer
# 30: man,woman,life,world,men,young,knowledge,money,death,story
# 31: returns,enumerators,skins,hides,canning,returned,preserving,cases,distinguish,wagon
# 32: prices,demand,foreign,business,actual,price,reports,year,commerce,exports
# 33: materials,engaged,cost,occupations,expenses,primarily,salaries,different,pursuits,proportions
# 34: tho,sugar,aro,cane,beet,tile,beets,brick,molasses,somo
# 35: legs,feet,finish,dark,turned,slightly,hand,throw,internal,kept
# 36: century,french,italian,beauty,spread,sixteenth,saw,plane,constructed,popular
# 37: concerning,profits,brought,currency,worth,gallons,striking,corn,strict,gallon
# 38: style,taste,rich,composition,example,renaissance,expression,empire,contact,radio
# 39: view,joint,certain,necessity,intended,possible,principle,advantage,various,specific
# 40: law,examination,bar,attended,thirty,admitted,army,suit,millions,agents
# 41: industrial,insurance,buildings,financial,factory,efficiency,dollar,examined,extension,cents
# 42: time,study,long,experience,come,practical,influence,way,away,need
# 43: let,care,quite,make,best,girl,stand,remain,hard,look
# 44: years,ago,children,coal,mississippi,laborers,mainly,arkansas,negro,anthracite
# 45: workers,shop,shown,girls,shall,home,cause,season,meet,bring
# 46: just,getting,strain,sum,farmer,markets,begins,needed,maintain,owners
# 47: book,metal,designed,similar,contain,illustrations,shell,manner,ornamental,contains
# 48: board,plan,mass,boston,member,opportunity,laws,russian,thousands,beginning
# 49: work,good,piece,say,end,things,doing,strength,purpose,principles
# 50: report,shops,stated,special,machine,account,connection,attention,present,regarding
# 51: old,school,difficult,child,word,little,anti,author,person,instruction
# 52: period,greatest,highest,gain,showed,absolute,led,took,connecticut,louisiana
# 53: set,point,right,strong,position,fashion,bad,appearance,foundation,dull
# 54: automobile,arranged,motor,principally,flour,remainder,car,vehicles,building,sixth
# 55: case,timber,jointing,appear,sooner,main,ascertain,lasting,ascertained,calculated
# 56: class,earlier,silk,variation,affected,textile,differences,throwing,body,carriages
# 57: room,words,rooms,broken,equally,treatment,allowing,perfect,increasing,based
# 58: fact,left,free,clock,space,deal,receive,immediately,follows,holding
# 59: days,having,hold,face,sure,composed,skilled,writers,narrow,gathering

# %%
results=topic_model.predict(doc_word[len(documents_mod):])
results.shape
# Out:
# (436, 60)

# %% [markdown]
# ## Total Corelation and Model Selection

# %%
topic_model.tc
# Out:
# 10.908955347445406

# %%
tc_lst=[[i,v] for i,v in enumerate(topic_model.tcs)]
tc_df=pd.DataFrame(tc_lst,columns=['topic','tc'])

# %%
import altair as alt
chart=alt.Chart(tc_df).mark_bar().encode(x='topic',y='tc',tooltip=tc_df.columns.tolist()).properties(
    width=800)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# If you hover over, you can see that topic 6 is the cut-off boundary

# %%
chart.save('Tc_distr_v1.html')

# %% [markdown]
# ## Pointwise Document TC

# %% [markdown]
# We can decompose total correlation further. The topic correlation is the average of the pointwise total correlations for each individual document. The pointwise total correlations can be accessed through log_z.

# %%
topic_model.log_z # n_docs x k_topics
# Out:
# array([[ 6.72245176e-01,  1.03118370e+00,  3.69992241e-01, ...,
#          6.26871583e-04,  5.17512531e-04,  4.30086612e-03],
#        [ 6.72245176e-01,  1.03118370e+00,  6.10666196e+00, ...,
#          6.19319202e-04,  6.19277451e-04,  4.59703268e-03],
#        [ 6.72245176e-01, -7.04329269e-01,  3.69992241e-01, ...,
#          5.27477293e-04, -4.45644430e-02,  4.71528573e-03],
#        ...,
#        [ 6.72245176e-01,  1.03118370e+00,  3.91223953e+00, ...,
#          6.15037245e-04,  6.97142366e-04,  5.20443440e-03],
#        [ 6.72245176e-01,  1.03118370e+00, -2.46711285e+00, ...,
#          6.18836853e-04,  6.33443118e-04,  4.47511344e-03],
#        [ 6.72245176e-01, -1.27046635e+00, -9.68812794e-01, ...,
#          4.41100872e-04, -2.76274188e-05,  3.15705831e-03]])

# %%
print(np.mean(topic_model.log_z, axis=0)) #The pointwise total correlations in log_z represent the correlations within an individual document explained by a particular topic. These correlations have been used to measure how "surprising" documents are with respect to given topics
print(topic_model.tcs)

# %% [markdown]
# ## Introducing Anchoring in the semi-supervised topic mode

# %% [markdown]
# CorEx is a discriminative model, whereas LDA is a generative model. This means that while LDA outputs a probability distribution over each document, CorEx instead estimates the probability a document belongs to a topic given that document's words. As a result, the probabilities across topics for a given document do not have to add up to 1. The estimated probabilities of topics for each document can be accessed through log_p_y_given_x or p_y_given_x.
#
# Hierarchical Topic Models The labels attribute gives the binary topic expressions for each document and each topic. We can use this output as input to another CorEx topic model to get latent representations of the topics themselves. This yields a hierarchical CorEx topic model. Like the first layer of the topic model, one can determine the number of latent variables to add in higher layers through examination of the topic TCs.
#
# Anchored CorEx is an extension of CorEx that allows the "anchoring" of words to topics. When anchoring a word to a topic, CorEx is trying to maximize the mutual information between that word and the anchored topic. So, anchoring provides a way to guide the topic model towards specific subsets of words that the user would like to explore.
#
# Anchoring a single set of words to a single topic. This can help promote a topic that did not naturally emerge when running an unsupervised instance of the CorEx topic model. For example, one might anchor words like "snow," "cold," and "avalanche" to a topic if one suspects there should be a snow avalanche topic within a set of disaster relief articles.
#
# Anchoring single sets of words to multiple topics. This can help find different aspects of a topic that may be discussed in several different contexts. For example, one might anchor "protest" to three topics and "riot" to three other topics to understand different framings that arise from tweets about political protests.
#
# Anchoring different sets of words to multiple topics. This can help enforce topic separability if there appear to be chimera topics. For example, one might anchor "mountain," "Bernese," and "dog" to one topic and "mountain," "rocky," and "colorado" to another topic to help separate topics that merge discussion of Bernese Mountain Dogs and the Rocky Mountains.

# %%
#to automatically generate anchor words: for each label in a data set, 
#we find the words that have the highest mutual information with the label.
# we took a very simple to automatically generate the anchor words to create a semi-supervised model

for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    anchor_words.append(list(topic_words[:3]))
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-416f1311753b> in <module>
#       3 # we took a very simple to automatically generate the anchor words to create a semi-supervised model
#       4 anchor_words=[]
# ----> 5 for n,topic in enumerate(topics):
#       6     topic_words,_,_ = zip(*topic)
#       7     anchor_words.append(list(topic_words[:3]))
#
# NameError: name 'topics' is not defined

# %%
#manually adjust the anchor words based on the observation
anchor_words=[None]*60
anchor_words[0]=['manufacturing','mechanical','industry']
anchor_words[1]=['water','wood','boil']
anchor_words[2]=['workers','organizations','committee']
anchor_words[3]=['furniture','wood','carve','carpenters','workmen'] 
anchor_words[7]=['forgemen','harmmermen']
anchor_words[8]=['market','trade','stock','sales']
anchor_words[11]=['university','institute','education','professional'] 
anchor_words[13]=['forestry','agriculture','husbandry'] 
anchor_words[14]=['electric','power','mechanic','engines'] 
anchor_words[18]=['iron','blacksmiths','steel']
anchor_words[20]=['art','gallery','artists']
anchor_words[26]=['machinery','machinists','apparatus']
anchor_words[31]=['meat','butchers','slaughtering']
anchor_words[32]=['textile','fabrics','clothing','tailors']
anchor_words[37]=['family','house','personal']
anchor_words[38]=['coal','miners']
anchor_words[39]=['court','justice','lawyers','judge']
anchor_words[47]=['household','domestic','house']
anchor_words[49]=['public','school','teachers']
anchor_words[51]=['clerks','shop']
anchor_words[56]=['book','publishing','authors']

# %% [markdown]
# # Predict

# %%
df_occsc = pd.read_csv('../../OCC_pairs.csv').rename(columns={'OCC_DES':'Full Occupation'})
assert(df_occsc['Full Occupation'].nunique() == len(df_occsc))
occ_original = list(set(list(df_occsc['Full Occupation'])))

# %%
def get_predict_result(results):
    pairs=[]
    for i in range(len(results)):
        for j in range(len(results[i])):
            if results[i][j]==True:
                pairs.append([i,j])
    return pairs

#might change the threshold
#get log_p_y_given_x for each doc
def get_predict_proba(results_proba):
    pairs_proba={i:[] for i in range(len(results_proba))}
    #i: document num
    for i in range(len(results_proba)):
        #j: topic num for each doc
        for j in range(len(results_proba[i])):
            #threshold
            if results_proba[i][j] >= 1e-3:
                pairs_proba[i].append((j,results_proba[i][j]))
    return pairs_proba

def count_topics(pairs):
    available={}
    for a,b in pairs:
        if b not in available.keys():
            available[b]=1
        else:
            available[b]+=1
    return available 

def get_topic_content(pairs,topic):
    result=[]
    for a,b in pairs:
        if b == topic:
            result.append(occ_list[a])
    return result 

def get_topic_list(pairs):
    result={}
    for a,b in pairs:
        if b not in result.keys():
            result[b]=[a]
        else:
            result[b].append(a)
    return result

def save_topic(pairs):
    result_dic=get_topic_list(pairs)
    with open("train_result_30.txt",'w') as f:
        for m,n in result_dic.items():
            topic_words,_,_ = zip(*anchored_topic_model.get_topics(topic=m))
            title=str(m)+":"+(','.join(topic_words))
            f.write(title+'\n')
            for file in n:
                occ_title=occ_list[file]
                f.write(occ_title+'\n')
            f.write("\n \n \n")

# %%
m1 = ct.Corex(n_hidden=10, words=words)
m1.fit(doc_word[:len(documents_mod)], words=words);
results=m1.transform(doc_word[len(documents_mod):])
# Out:
# WARNING: Some words never appear (or always appear)

# %%
results_proba,mutual=m1.transform(doc_word[len(documents_mod):],details=True)

# %% [markdown]
# CorEx is a *discriminative* model, whereas LDA is a *generative* model. This means that while LDA outputs a probability distribution over each document, CorEx instead estimates the probability a document belongs to a topic given that document's words.
#
# As a result, the probabilities across topics for a given document do not have to add up to 1.
#
# The estimated probabilities of topics for each document can be accessed through **`log_p_y_given_x`** or **`p_y_given_x`**.

# %% [markdown]
# The pointwise total correlations in **`log_z`** represent the correlations within an individual document explained by a particular topic.
#
# These correlations have been used to measure how "surprising" documents are with respect to given topics (see references below).

# %%
#just an idea of how pairs_proba looks like
results=m1.transform(doc_word[len(documents_mod):])
results_proba,mutual=m1.transform(doc_word[len(documents_mod):],details=True)
pairs=get_predict_result(results)
pairs_proba=get_predict_proba(results_proba)
pairs_proba
# Out:
# {0: [(0, 0.11269283414755432),
#   (1, 0.9980665365780593),
#   (2, 0.009136935274991433),
#   (5, 0.001156073077800987),
#   (6, 0.999985190679667),
#   (7, 0.002188671934248975),
#   (8, 0.9999689898762059),
#   (9, 0.5795044603758198)],
#  1: [(1, 0.9834689346895956),
#   (2, 0.0011527096540375245),
#   (3, 0.3926636813608346),
#   (5, 0.004957740468268012),
#   (6, 0.004086436152807023),
#   (7, 0.002197941040551955),
#   (8, 0.0038798426305644506),
#   (9, 0.009877260894157363)],
#  2: [(1, 0.9959450846213578),
#   (4, 0.0029413813567235924),
#   (6, 0.7223389443345318),
#   (7, 0.0021885611207420044),
#   (8, 0.003764469964074015),
#   (9, 0.010350585795189111)],
#  3: [(0, 0.06073173430608161),
#   (1, 0.9980663568020246),
#   (2, 0.9970092857060747),
#   (5, 0.001791389426020898),
#   (6, 0.004081406099788789),
#   (7, 0.0021884489967238553),
#   (8, 0.004042347143197388),
#   (9, 0.9989795069530735)],
#  4: [(1, 0.9980663563613745),
#   (2, 0.0024871399836268954),
#   (5, 0.21373683399059207),
#   (6, 0.999917840485775),
#   (7, 0.002188799375052486),
#   (8, 0.004051859302660301),
#   (9, 0.009663065782143184)],
#  5: [(1, 0.9980663536977551),
#   (5, 0.999999),
#   (6, 0.9999188664833448),
#   (7, 0.0021938620033926867),
#   (8, 0.22603715648090897),
#   (9, 0.009707644699485433)],
#  6: [(1, 0.9980663533834626),
#   (4, 0.005510934269175431),
#   (5, 0.0017912211786364168),
#   (6, 0.003973177469839505),
#   (7, 0.0021887795133003446),
#   (8, 0.0040508453851998225),
#   (9, 0.5623176403473324)],
#  7: [(1, 0.9980663536484335),
#   (4, 0.002941163353105659),
#   (6, 0.7223402030005522),
#   (7, 0.0021885036890616967),
#   (8, 0.004044448353500718),
#   (9, 0.009661092974421368)],
#  8: [(0, 0.11103284573922818),
#   (1, 0.9703817335182731),
#   (4, 0.999693215637771),
#   (6, 0.003976658313735436),
#   (7, 0.0021865905447820094),
#   (8, 0.004024583057693088),
#   (9, 0.9999400479095555)],
#  9: [(1, 0.9980663536484313),
#   (4, 0.002941561954883259),
#   (5, 0.999999),
#   (6, 0.999999),
#   (7, 0.9999307130702723),
#   (8, 0.016603217400506798),
#   (9, 0.009662079849736507)],
#  10: [(0, 0.8089898889397859),
#   (1, 0.9980665457654384),
#   (4, 0.004112763374768186),
#   (5, 0.0011560613529158418),
#   (6, 0.003961949301141155),
#   (7, 0.9877880616718967),
#   (8, 0.004060623540901978),
#   (9, 0.9999810451196781)],
#  11: [(1, 0.9980663495413966),
#   (2, 0.9974024676762591),
#   (4, 0.999994428338479),
#   (5, 0.9998971122360152),
#   (6, 0.9999202300692704),
#   (7, 0.002189222722447222),
[(0, 0.009118283594134928),
#   (1, 0.9980665345994021),
#   (5, 0.0011560916085974111),
#   (6, 0.0039634058533221835),
#   (7, 0.9999307052252047),
#   (8, 0.004055990527653131),
#   (9, 0.009624290189187654)],
#  427: [(1, 0.9980663536985479),
#   (2, 0.9974024687955841),
#   (4, 0.006378505619436425),
#   (6, 0.003965974951508823),
#   (7, 0.0021887756223998474),
#   (8, 0.004048343658267798),
#   (9, 0.009666323858011468)],
#  428: [(0, 0.027904411968656565),
#   (1, 0.9980665361210364),
#   (2, 0.999999),
#   (4, 0.0041127437121321435),
#   (5, 0.0011533241196335707),
#   (6, 0.004067090579068865),
#   (7, 0.002267854274916202),
#   (8, 0.004096540121323716),
#   (9, 0.9999810354796084)],
#  429: [(1, 0.9980667867631421),
#   (5, 0.0026965034775495314),
#   (6, 0.05659565093729823),
#   (7, 0.048649225685522386),
#   (8, 0.9999470121908186),
#   (9, 0.06454641441709945)],
#  430: [(0, 0.009118283594134928),
#   (1, 0.9980665345994021),
#   (4, 0.004112773033063643),
#   (5, 0.0011560916085974111),
#   (6, 0.003963408395957982),
#   (7, 0.0021882487600080637),
#   (8, 0.004055990527735519),
#   (9, 0.9999810756119738)],
#  431: [(1, 0.9896547606871307),
#   (2, 0.9974014329937921),
#   (4, 0.9999734242653777),
#   (5, 0.02229187830296161),
#   (6, 0.004092605918842666),
#   (7, 0.002186844890517506),
#   (8, 0.00410535470231838),
#   (9, 0.8090100327721168)],
#  432: [(1, 0.998066353630943),
#   (4, 0.9999045648256827),
#   (6, 0.999999),
#   (7, 0.002188320105994655),
#   (8, 0.00405873387902945),
#   (9, 0.009628519306769022)],
#  433: [(0, 0.009147849065506143),
#   (1, 0.9980665356526768),
#   (4, 0.004112761220526297),
#   (5, 0.0011558241868196838),
#   (6, 0.0040707209360887784),
#   (7, 0.02998528359076713),
#   (8, 0.004082341665683595),
#   (9, 0.9999812245093268)],
#  434: [(1, 0.9699708450944359),
#   (4, 0.9999977537928121),
#   (6, 0.05669782171406881),
#   (7, 0.0021884551705967973),
#   (8, 0.004030673073721839),
#   (9, 0.00969226537196357)],
#  435: [(1, 0.998066343034351),
#   (5, 0.03886413195984674),
#   (6, 0.003966064236225691),
#   (7, 0.0021887691841130023),
#   (8, 0.00405208504858437),
#   (9, 0.18315893317436677)]}

# %%
def train_model(topic_num,anchor_w=anchor_words):
    anchored_topic_model= ct.Corex(n_hidden=topic_num, seed=2)
    anchored_topic_model.fit(doc_word[:len(documents_mod)], words=words, anchors=anchor_w, anchor_strength=10)
    print("-"*12,"topic words","-"*12)
    for n in range(topic_num):
        topic_words,_,_ = zip(*anchored_topic_model.get_topics(topic=n))
        print('{}: '.format(n) + ','.join(topic_words))
    print("-"*12,"print total correlation","-"*12)
    print(anchored_topic_model.tc)
    #predict
    results=anchored_topic_model.predict(doc_word[len(documents_mod):])
    results_proba,mutual_info=anchored_topic_model.predict_proba(doc_word[len(documents_mod):])
    
    pairs=get_predict_result(results)
    pairs_proba=get_predict_proba(results_proba)
    
    has_categorized=[]
    
    #a is the document index, d is the topic number it belongs to
    for a,b in pairs:
        if a not in has_categorized:
            has_categorized.append(a)
    print("-"*12,"occ that have been categorized into certain types","-"*12)
    print(len(has_categorized))

    has_not_categorized=[]
    for i in range(len(occ_original)):
        if i not in has_categorized:
            has_not_categorized.append(occ_original[i])
          
    print("-"*12,"has_not_categorized","-"*12)
    print(has_not_categorized)

    print("-"*12,"corresponding counts of topic","-"*12)
    print(count_topics(pairs))
    
    return anchored_topic_model,pairs,pairs_proba,has_not_categorized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-437a9fe94657> in <module>
# ----> 1 def train_model(topic_num,anchor_w=anchor_words):
#       2     anchored_topic_model= ct.Corex(n_hidden=topic_num, seed=2)
#       3     anchored_topic_model.fit(doc_word[:len(documents_mod)], words=words, anchors=anchor_w, anchor_strength=10)
#       4     print("-"*12,"topic words","-"*12)
#       5     for n in range(topic_num):
#
# NameError: name 'anchor_words' is not defined

# %%
def get_pairs_proba(anchored_model):
    #predict
    results=anchored_topic_model.predict(doc_word[len(documents_mod):])
    results_proba,mutual_info=anchored_topic_model.predict_proba(doc_word[len(documents_mod):])
    
    pairs=get_predict_result(results)
    pairs_proba=get_predict_proba(results_proba)
    
    has_categorized=[]
    
    #a is the document index, d is the topic number it belongs to
    for a,b in pairs:
        if a not in has_categorized:
            has_categorized.append(a)
    print("-"*12,"occ that have been categorized into certain types","-"*12)
    print(len(has_categorized))

    has_not_categorized=[]
    for i in range(len(occ_original)):
        if i not in has_categorized:
            has_not_categorized.append(occ_original[i])
          
    print("-"*12,"has_not_categorized","-"*12)
    print(has_not_categorized)

    print("-"*12,"corresponding counts of topic","-"*12)
    print(count_topics(pairs))
    
    return pairs,pairs_proba,has_not_categorized

# %%
#save model:
#must have hyperparameter set to "False" to preserve word labels!!
anchored_topic_model.save('Amanda_model/Amanda.dat',False)

# %%
import pickle as pkl

#load model:
model_path='Amanda.dat'
if os.path.exists(model_path):
    print('loaded from old')
    with open(model_path, 'rb') as f:
        anchored_topic_model = pkl.load(f) 
        pairs,pairs_proba,has_not_categorized=get_pairs_proba(anchored_topic_model)
else:
    print('created from old')
    anchored_topic_model,pairs,pairs_proba,has_not_categorized =train_model(60,anchor_words)
# Out:
# loaded from old
# ------------ occ that have been categorized into certain types ------------
# 409
# ------------ has_not_categorized ------------
# ['Transportation Other occupations, semi-skilled Steam railroad', 'Transportation Express, post, telegraph, and telephone, selected occupations Agents -- express companies', 'Transportation Laborers Locomotive firemen', 'Extraction of Minerals Operators, officials and managers Operators', 'Transportation Switchmen, flagmen, and yardmen Switchmen and flagmen --steam railroad', 'Clerical Occupations Agents, canvassers, and collectors Agents', 'Clerical Occupations Agents, canvassers, and collectors Canvassers', 'Transportation Laborers, not otherwise specified Other transportation', 'Transportation Motormen Steam railroad', 'Transportation Laborers Steam railroad', 'Transportation Baggagemen and freight agents Conductors -- steam railroad', 'Clerical Occupations Agents, canvassers, and collectors Collectors', 'Clerical Occupations Bookkeepers, cashiers, and accountants Accountants and auditors', 'Transportation Laborers, not otherwise specified Express companies', 'Transportation Inspectors Steam railroad', 'Transportation Laborers Locomotive engineers', 'Transportation Baggagemen and freight agents Brakemen', 'Transportation Other occupations, semi-skilled Other transportation', 'Transportation Laborers, not otherwise specified Telegraph and telephone', 'Transportation Other transportation pursuits: oremen and overseers, not otherwise specified Other transportation', 'Extraction of Minerals Operatives in other and not specified mines Mine operatives, n.s.', 'Transportation Foremen and overseers Steam railroad', 'Transportation Proprietors, officials, and messengers,not otherwise specified Telegraph and telephone', 'Transportation Baggagemen and freight agents Freight agents', 'Clerical Occupations Bookkeepers, cashiers, and accountants Bookkeepers and cashiers', 'Extraction of Minerals Oil, gas and salt well operatives Oil and gas well operatives', 'Extraction of Minerals Operatives in other and not specified mines Quarry operatives']
# ------------ corresponding counts of topic ------------
# {0: 185, 7: 52, 18: 26, 11: 53, 27: 92, 49: 21, 13: 11, 22: 12, 8: 84, 51: 25, 37: 37, 47: 39, 25: 18, 56: 13, 31: 7, 54: 5, 3: 15, 4: 22, 32: 33, 2: 3, 45: 3, 14: 2, 50: 4, 9: 2, 38: 10, 57: 13, 1: 11, 21: 4, 10: 2, 16: 2, 26: 7, 17: 4, 41: 2, 15: 1, 20: 2, 33: 1, 30: 3, 39: 1, 55: 1, 53: 1}

# %%
#just an idea of what a topic_helper dictionary looks like
topic_helper
# Out:
# {0: [(33, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (28, 0.999999),
#   (28, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (28, 0.999999),
#   (26, 0.999999),
#   (23, 0.999999),
#   (26, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (34, 0.999999),
#   (20, 0.999999),
#   (26, 0.999999),
#   (23, 0.999999),
#   (31, 0.999999),
#   (26, 0.999999),
#   (23, 0.999999),
#   (28, 0.999999),
#   (32, 0.999999),
#   (28, 0.999999),
#   (32, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (25, 0.999999),
#   (25, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (29, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (24, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (37, 0.999999),
#   (20, 0.999999),
#   (29, 0.999999),
#   (23, 0.999999),
#   (19, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (30, 0.999999),
#   (31, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (21, 0.999999),
#   (25, 0.999999),
#   (19, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (21, 0.999999),
#   (23, 0.999999),
#   (30, 0.999999),
#   (15, 0.999999),
#   (32, 0.999999),
#   (23, 0.999999),
#   (30, 0.999999),
#   (23, 0.999999),
#   (30, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (32, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (29, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (34, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (38, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (30, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (46, 0.999999),
#   (24, 0.999999),
#   (20, 0.999999),
#   (33, 0.999999),
#   (17, 0.999999),
#   (28, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (25, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (36, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (30, 0.999999),
#   (23, 0.999999),
#   (27, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (38, 0.999999),
#   (20, 0.999999),
#   (24, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (32, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (21, 0.999999),
#   (23, 0.999999),
#   (27, 0.999999),
#   (26, 0.999999),
#   (12, 0.999999),
#   (20, 0.999999),
#   (27, 0.999999),
#   (23, 0.999999),
#   (36, 0.999999),
#   (34, 0.999999),
#   (20, 0.999999),
#   (47, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (47, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999)],
#  1: [(38, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (32, 0.999999),
#   (20, 0.999999),
#   (30, 0.999999),
#   (25, 0.999999),
#   (20, 0.999999)],
#  2: [(34, 0.999999),
#   (32, 0.999999),
#   (42, 0.006645101579964469),
#   (15, 0.999999)],
#  3: [(23, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (21, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (24, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999)],
#  4: [(23, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.33758821142874856),
#   (20, 0.33757929998520936),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999
#   (33, 0.014706281565419463),
#   (38, 0.014706278690985996),
#   (16, 0.014706991982485694),
#   (20, 0.17749418631521802),
#   (23, 0.1775204462571827),
#   (23, 0.6881826801263821),
#   (23, 0.3572026243968543),
#   (30, 0.014706278736439019),
#   (23, 0.014703427311077452),
#   (14, 0.014705955090390428),
#   (20, 0.014707035511969328),
#   (11, 0.01470627881610774),
#   (23, 0.3572146037693146),
#   (27, 0.014706278716524255),
#   (9, 0.014707035325306428),
#   (25, 0.014706278718667474),
#   (23, 0.6587099340751653),
#   (35, 0.006233106195012767),
#   (30, 0.602329051544424),
#   (23, 0.35720266105316056),
#   (20, 0.014706278716524255),
#   (15, 0.014706278589137058),
#   (9, 0.01470341181531722),
#   (27, 0.1775204008303135),
#   (23, 0.644607988919584),
#   (27, 0.38242136664307314),
#   (23, 0.17752044625802085),
#   (20, 0.014706991982485682),
#   (23, 0.17746954698388998),
#   (38, 0.17752043720182872),
#   (25, 0.014705430423841329),
#   (38, 0.014706278716524255),
#   (20, 0.1775280733023927),
#   (9, 0.01470341181531722),
#   (42, 0.8344118689390848),
#   (24, 0.17752035994569515),
#   (26, 0.014706278694754767),
#   (23, 0.1775206993205229),
#   (25, 0.014706278701561088),
#   (18, 0.01470627872714722),
#   (36, 0.014706280231167651),
#   (38, 0.014706278718667474),
#   (20, 0.35721166884602173),
#   (20, 0.7960981380566393),
#   (20, 0.9704231460416833),
#   (20, 0.014708089416177376),
#   (23, 0.17752041067713178),
#   (20, 0.9999978057752287),
#   (38, 0.014706277682987393),
#   (20, 0.014707038368550045),
#   (23, 0.9410636679045037),
#   (27, 0.01470627872714722),
#   (20, 0.35721466011225306),
#   (23, 0.17752035858672768),
#   (32, 0.17752044761615063),
#   (40, 0.014706280233310871),
#   (23, 0.014703421432091197),
#   (20, 0.17752807395953896),
#   (42, 0.014706280238659573),
#   (23, 0.35720266095079267),
#   (20, 0.5107402300210236),
#   (20, 0.09481632989374333),
#   (21, 0.17752035994569515),
#   (23, 0.17752558371428181),
#   (39, 0.014676621209955432),
#   (24, 0.09481184673857827),
#   (42, 0.014713423764370097),
#   (27, 0.17752040083039985),
#   (16, 0.014702635361037464),
#   (26, 0.17746963463448284),
#   (12, 0.17752044761606423),
#   (42, 0.34309062778806326),
#   (20, 0.1775280733023927),
#   (24, 0.014706278879209111),
#   (27, 0.1775204008303135),
#   (23, 0.35720266095327563),
#   (42, 0.014706278793232533),
#   (24, 0.014706281394640336),
#   (35, 0.014706278504832549),
#   (36, 0.1775204476161522),
#   (34, 0.01466627697039294),
#   (25, 0.014706278701561088),
#   (20, 0.1775280500651338),
#   (47, 0.17752044761615063),
#   (19, 0.17752035994569515),
#   (20, 0.17752807330142956),
#   (33, 0.014706278718667474),
#   (24, 0.09481184673857827),
#   (30, 0.014707332567936103),
#   (25, 0.014690064767926671),
#   (23, 0.014706278718667474),
#   (38, 0.09481184752495117),
#   (42, 0.01470626237077203),
#   (11, 0.014592425962097443),
#   (24, 0.014707332567936103),
#   (36, 0.014710010761448355),
#   (20, 0.35721460026227364),
#   (23, 0.9510881768156154),
#   (23, 0.17752044698011707),
#   (42, 0.014706278793338568),
#   (30, 0.014706278793338568),
#   (23, 0.9555119010614505),
#   (20, 0.09474195481852368),
#   (42, 0.014706280231179108),
#   (20, 0.6495879275070043),
#   (23, 0.3572026609523123),
#   (20, 0.1775280733023927),
#   (47, 0.17752044761615063),
#   (22, 0.014706278690985996),
#   (23, 0.5842879501780237),
#   (3, 0.11145599944034387),
#   (23, 0.1775204462571827),
#   (21, 0.014649508355000944),
#   (26, 0.014706277470811761),
#   (23, 0.35720262439496525),
#   (22, 0.014706278704933084)],
#  8: [(42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (29, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (30, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (24, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (9, 0.999999),
#   (12, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (14, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (23, 0.10665653026396231),
#   (29, 0.999999),
#   (24, 0.999999),
#   (23, 0.999999),
#   (26, 0.999999),
#   (20, 0.999999),
#   (12, 0.999999),
#   (31, 0.999999),
#   (42, 0.999999),
#   (25, 0.999999),
#   (20, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (26, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (38, 0.1066568938566721),
#   (23, 0.10638134310818577),
#   (40, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (13, 0.999999),
#   (42, 0.999999),
#   (24, 0.999999),
#   (42, 0.999999),
#   (33, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (14, 0.999999),
#   (9, 0.999999),
#   (35, 0.999999),
#   (27, 0.999999),
#   (42, 0.999999),
#   (36, 0.999999),
#   (38, 0.999999),
#   (27, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (24, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (30, 0.999999),
#   (42, 0.999999),
#   (3, 0.999999),
#   (26, 0.999999),
#   (42, 0.999999)],
#  9: [(16, 0.9988789797007845),
#   (23, 0.004205273931675867),
#   (29, 0.9988715779987153),
#   (24, 0.0031591543545082725),
#   (11, 0.0020153948758970795)],
#  10: [(19, 0.999999),
#   (4, 0.9999984436365562),
#   (14, 0.24309241828871544),
#   (19, 0.006592827700462436)],
#  11: [(31, 0.999999),
#   (19, 0.999999),
#   (16, 0.999999),
#   (34, 0.999999),
#   (5, 0.9381805136924156),
#   (14, 0.999999),
#   (42, 0.999999),
#   (62, 0.999999),
#   (4, 0.999999),
#   (42, 0.999999),
#   (63, 0.999999),
#   (4, 0.999999),
#   (54, 0.999999),
#   (33, 0.999999),
#   (33, 0.999999),
#   (14, 0.999999),
#   (13, 0.999999),
#   (42, 0.999999),
#   (26, 0.999999),
#   (20, 0.999999),
#   (40, 0.999999),
#   (27, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (13, 0.999999),
#   (46, 0.999999),
#   (18, 0.999999),
#   (20, 0.999999),
#   (29, 0.999999),
#   (33, 0.999999),
#   (22, 0.999999),
#   (24, 0.999999),
#   (41, 0.999999),
#   (15, 0.999999),
#   (80, 0.999999),
#   (46, 0.999999),
#   (7, 0.999999),
#   (23, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (27, 0.999999),
#   (20, 0.999999),
#   (38, 0.999999),
#   (42, 0.999999),
#   (38, 0.999999),
#   (40, 0.999999),
#   (42, 0.999999),
#   (39, 0.999999),
#   (47, 0.49445561479151773),
#   (33, 0.999999),
#   (7, 0.999999),
#   (11, 0.9381805136924156),
#   (46, 0.999999),
#   (21, 0.999999),
#   (47, 0.49445561479151773)],
#  12: [],
#  13: [(15, 0.15567520456075185),
#   (14, 0.999999),
#   (12, 0.999999),
#   (9, 0.999999),
#   (14, 0.999999),
#   (17, 0.999999),
#   (9, 0.999999),
#   (14, 0.999999),
#   (9, 0.999999),
#   (9, 0.999999),
#   (9, 0.999999),
#   (16, 0.999999)],
#  14: [(23, 0.999999), (20, 0.999999)],
#  15: [(26, 0.4119521580685581),
#   (13, 0.41230511776861184),
#   (20, 0.999999),
#   (19, 0.41190780932941407)],
#  16: [(23, 0.0019081576723634656),
#   (34, 0.0022920144923493837),
#   (23, 0.9996305393682823),
#   (33, 0.002285301709592611),
#   (38, 0.0022920145143151332),
#   (32, 0.0022780958254061874),
#   (12, 0.0022920034651702417),
#   (35, 0.0024095277336646714),
#   (23, 0.9996271860170405),
#   (15, 0.001702411216373448),
#   (20, 0.0024004833979149433),
#   (21, 0.0022714455930200592)],
#  17: [(42, 0.999999),
#   (20, 0.007911070662630604),
#   (20, 0.8500723734775724),
#   (23, 0.8502702347066171),
#   (23, 0.999999),
#   (23, 0.007923271150081608)],
#  18: [(23, 0.999999),
#   (28, 0.999999),
#   (26, 0.999999),
#   (34, 0.999999),
#   (25, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (29, 0.999999),
#   (25, 0.999999),
#   (23, 0.999999),
#   (32, 0.999999),
#   (23, 0.999999),
#   (23, 0.0037415313929598836),
#   (29, 0.11150718323587862),
#   (42, 0.999999),
#   (34, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (24, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (12, 0.999999),
#   (36, 0.999999),
#   (34, 0.999999),
#   (20, 0.0037415400250036973)],
#  19: [(23, 0.0016824045100106305),
#   (42, 0.004595823367673316),
#   (20, 0.003052469066764158),
#   (20, 0.0016782093641408084),
#   (20, 0.19046170214406077),
#   (23, 0.0030602236814438618),
#   (23, 0.19085441431200378)],
#  20: [(31, 0.999999),
#   (42, 0.999999),
#   (36, 0.026654195684747178),
#   (26, 0.026654195684747178),
#   (24, 0.026654195684747178)],
#  21: [(23, 0.999999), (23, 0.999999), (42, 0.999999), (20, 0.999999)],
#  22: [(14, 0.999999),
#   (12, 0.999999),
#   (9, 0.999999),
#   (14, 0.999999),
#   (17, 0.999999),
#   (9, 0.999999),
#   (22, 0.999999),
#   (38, 0.3904147459582675),
#   (14, 0.999999),
#   (9, 0.999999),
#   (9, 0.999999),
#   (9, 0.999999),
#   (16, 0.999999),
#   (22, 0.3904147460329703)],
#  23: [],
#  24: [(42, 0.0017971607950531434),
#   (15, 0.0017968237928020013),
#   (28, 0.0017971759141850506),
#   (28, 0.0017971758402932525),
#   (34, 0.0017970137139213932),
#   (33, 0.0017970123156821137),
#   (15, 0.0017968341380852808),
#   (38, 0.0017970137139213932),
#   (32, 0.0017970139040343804),
#   (12, 0.001797013713763973),
#   (0, 0.0017968237914774586),
#   (42, 0.0018045898784732534),
#   (23, 0.0017971758402932525),
#   (21, 0.0017970125061097964)],
#  25: [(15, 0.195951732177956),
#   (22, 0.999999),
#   (38, 0.999999),
#   (34, 0.999999),
#   (38, 0.999999),
#   (33, 0.999999),
#   (63, 0.1959516654855881),
#   (15, 0.19595170395832248),
#   (36, 0.999999),
#   (23, 0.999999),
#   (26, 0.999999),
#   (42, 0.999999),
#   (27, 0.19567026900632425),
#   (40, 0.19595166719053864),
#   (25, 0.999999),
#   (0, 0.1959517321779038),
#   (20, 0.999999),
#   (33, 0.1959516654855881),
#   (24, 0.19595166546934145),
#   (41, 0.19595166834073516),
#   (22, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (16, 0.999999),
#   (20, 0.999999),
#   (20, 0.999999),
#   (42, 0.19595166548654946),
#   (20, 0.1959516457567766),
#   (39, 0.1959516654855881),
#   (42, 0.999999)],
#  26: [(33, 0.4507634106772191),
#   (28, 0.999999),
#   (37, 0.999999),
#   (42, 0.978493599447124),
#   (31, 0.4538923987103688),
#   (32, 0.999999),
#   (20, 0.45363430100405283),
#   (20, 0.999999),
#   (42, 0.999999),
#   (42, 0.45516253863987843),
#   (24, 0.999999),
#   (21, 0.4567380059801344)],
#  27: [(31, 0.999999),
#   (19, 0.999999),
#   (32, 0.999999),
#   (16, 0.999999),
#   (6, 0.999999),
#   (34, 0.999999),
#   (5, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (15, 0.999999),
#   (62, 0.999999),
#   (4, 0.999999),
#   (23, 0.999999),
#   (42, 0.999999),
#   (63, 0.999999),
#   (11, 0.999999),
#   (4, 0.999999),
#   (54, 0.999999),
#   (33, 0.999999),
#   (33, 0.999999),
#   (23, 0.999999),
#   (36, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (33, 0.999999),
#   (6, 0.999999),
#   (13, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (32, 0.999999),
#   (26, 0.999999),
#   (36, 0.999999),
#   (15, 0.999999),
#   (27, 0.999999),
#   (20, 0.999999),
#   (15, 0.999999),
#   (27, 0.999999),
#   (40, 0.999999),
#   (27, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (13, 0.999999),
#   (13, 0.999999),
#   (46, 0.999999),
#   (18, 0.999999),
#   (18, 0.999999),
#   (20, 0.999999),
#   (29, 0.999999),
#   (36, 0.999999),
#   (33, 0.999999),
#   (11, 0.999999),
#   (22, 0.999999),
#   (24, 0.999999),
#   (41, 0.999999),
#   (15, 0.999999),
#   (80, 0.999999),
#   (46, 0.999999),
#   (6, 0.999999),
#   (6, 0.999999),
#   (7, 0.999999),
#   (23, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (11, 0.999999),
#   (27, 0.999999),
#   (25, 0.999999),
#   (20, 0.999999),
#   (15, 0.999999),
#   (11, 0.999999),
#   (38, 0.999999),
#   (42, 0.999999),
#   (18, 0.999999),
#   (38, 0.999999),
#   (20, 0.999999),
#   (40, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (39, 0.999999),
#   (33, 0.999999),
#   (30, 0.999999),
#   (25, 0.999999),
#   (23, 0.999999),
#   (7, 0.999999),
#   (11, 0.999999),
#   (24, 0.999999),
#   (36, 0.999999),
#   (46, 0.999999),
#   (21, 0.999999),
#   (22, 0.999999)],
#  28: [],
#  29: [(23, 0.03120489612810378), (23, 0.031145206768688885)],
#  30: [(9, 0.999999), (9, 0.999999), (9, 0.999999), (16, 0.2984224920649783)],
#  31: [(29, 0.999999),
#   (23, 0.9996742025265738),
#   (23, 0.9582433672047421),
#   (29, 0.999999),
#   (40, 0.9998262334061323),
#   (23, 0.9585236885511863),
#   (20, 0.9996760192734099)],
#  32: [(23, 0.999999),
#   (20, 0.9999253444581302),
#   (34, 0.9531966143606679),
#   (26, 0.999999),
#   (23, 0.999999),
#   (26, 0.954657935080038),
#   (28, 0.954657935080038),
#   (42, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.9546107450540501),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (15, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (38, 0.0022105988499917712),
#   (20, 0.999999),
#   (23, 0.999999),
#   (36, 0.999999),
#   (20, 0.999999)],
#  33: [(42, 0.999999)],
#  34: [],
#  35: [(31, 0.0012562084317906724)],
#  36: [],
#  37: [(19, 0.999999),
#   (6, 0.999999),
#   (5, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (4, 0.999999),
#   (23, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (15, 0.999999),
#   (15, 0.999999),
#   (13, 0.999999),
#   (18, 0.999999),
#   (18, 0.999999),
#   (20, 0.999999),
#   (11, 0.999999),
#   (6, 0.999999),
#   (6, 0.999999),
#   (7, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (11, 0.999999),
#   (25, 0.999999),
#   (15, 0.999999),
#   (18, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (7, 0.999999),
#   (11, 0.999999),
#   (22, 0.999999)],
#  38: [(32, 0.08023176428238805),
#   (14, 0.9988350106737041),
#   (20, 0.999999),
#   (36, 0.080231765516829),
#   (36, 0.080231765516829),
#   (20, 0.999999),
#   (17, 0.9988350106737041),
#   (20, 0.999999),
#   (20, 0.999999),
#   (42, 0.999999),
#   (20, 0.999999),
#   (11, 0.0804301889525491),
#   (24, 0.999999),
#   (36, 0.080231765516829),
#   (3, 0.999999)],
#  39: [(62, 0.999999),
#   (32, 0.056803023610536546),
#   (27, 0.05680302361226935),
#   (25, 0.05680085025967234),
#   (23, 0.05678532603725495),
#   (20, 0.05667271118039871),
#   (30, 0.056803023610536546),
#   (24, 0.056803023610536546)],
#  40: [(42, 0.009161789369173444)],
#  41: [(36, 0.999999), (42, 0.999999)],
#  42: [(23, 0.14484772158128092), (20, 0.14484772153047937)],
#  43: [],
#  44: [],
#  45: [(34, 0.999999), (32, 0.999999), (15, 0.999999)],
#  46: [(43, 0.47308144662345253),
#   (33, 0.4730883646411724),
#   (23, 0.4730390552005687)],
#  47: [(19, 0.999999),
#   (6, 0.999999),
#   (5, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (4, 0.999999),
#   (23, 0.999999),
#   (14, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (6, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (15, 0.999999),
#   (15, 0.999999),
#   (26, 0.6209626683033952),
#   (13, 0.999999),
#   (18, 0.999999),
#   (18, 0.999999),
#   (20, 0.999999),
#   (11, 0.999999),
#   (6, 0.999999),
#   (6, 0.999999),
#   (7, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (11, 0.999999),
#   (25, 0.999999),
#   (15, 0.999999),
#   (18, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (23, 0.999999),
#   (7, 0.999999),
#   (11, 0.999999),
#   (26, 0.6211114767995957),
#   (22, 0.999999)],
#  48: [(38, 0.20133656356657237)],
#  49: [(31, 0.999999),
#   (32, 0.999999),
#   (16, 0.999999),
#   (15, 0.999999),
#   (11, 0.999999),
#   (23, 0.999999),
#   (36, 0.999999),
#   (33, 0.999999),
#   (42, 0.10114666852057462),
#   (32, 0.999999),
#   (26, 0.10090730740943325),
#   (36, 0.999999),
#   (27, 0.999999),
#   (20, 0.999999),
#   (27, 0.999999),
#   (36, 0.999999),
#   (40, 0.10090738006976706),
#   (27, 0.999999),
#   (11, 0.999999),
#   (20, 0.999999),
#   (30, 0.999999),
#   (25, 0.999999),
#   (24, 0.999999),
#   (36, 0.999999)],
#  50: [(20, 0.999999),
#   (23, 0.999999),
#   (42, 0.5680793739188829),
#   (35, 0.5680793049910242)],
#  51: [(42, 0.9999359275712656),
#   (15, 0.9979115029922307),
#   (42, 0.03243521303674298),
#   (34, 0.999999),
#   (30, 0.9999359275261002),
#   (23, 0.003416455945248142),
#   (42, 0.0034649582580474777),
#   (42, 0.0034646571976706267),
#   (23, 0.0014097849179340624),
#   (33, 0.999999),
#   (12, 0.9999359275261002),
#   (15, 0.9979116550472373),
#   (42, 0.003464967907068881),
#   (42, 0.9997332216299577),
#   (38, 0.999999),
#   (19, 0.9979563352758918),
#   (32, 0.999999),
#   (12, 0.999999),
#   (27, 0.001471660604140936),
#   (24, 0.9999359292932302),
#   (0, 0.997911502728273),
#   (42, 0.003167938650291905),
#   (31, 0.9999359275261002),
#   (42, 0.0014248739664192863),
#   (42, 0.0034649711269439426),
#   (42, 0.9997906088866434),
#   (24, 0.999999),
#   (22, 0.999999),
#   (7, 0.0010069661254363173),
#   (42, 0.003167938650291905),
#   (20, 0.003416209723155253),
#   (35, 0.0034650749492525315),
#   (26, 0.999999),
#   (25, 0.999999),
#   (20, 0.0014096831109469197),
#   (42, 0.0034646211007538373),
#   (12, 0.9979563359236027),
#   (24, 0.032435088435510406),
#   (24, 0.9999359290400489),
#   (36, 0.9979114135310521),
#   (25, 0.999999),
#   (21, 0.999999)],
#  52: [(42, 0.17046256976904456)],
#  53: [(25, 0.7655220193427059)],
#  54: [(22, 0.001108740980926765),
#   (42, 0.980556053498423),
#   (23, 0.999999),
#   (20, 0.999999),
#   (42, 0.0020331742539409434),
#   (22, 0.9991033444568884),
#   (20, 0.9807940697532438)],
#  55: [(23, 0.999999)],
#  56: [(63, 0.999999),
#   (20, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (23, 0.999999),
#   (20, 0.999999),
#   (40, 0.999999),
#   (33, 0.999999),
#   (24, 0.999999),
#   (23, 0.999999),
#   (41, 0.999999),
#   (20, 0.999999),
#   (39, 0.999999)],
#  57: [(14, 0.999999),
#   (42, 0.999999),
#   (4, 0.999999),
#   (14, 0.999999),
#   (42, 0.999999),
#   (42, 0.999999),
#   (42, 0.5749801592402279),
#   (20, 0.999999),
#   (7, 0.999999),
#   (19, 0.999999),
#   (20, 0.999999),
#   (42, 0.999999),
#   (7, 0.999999)],
#  58: [],
#  59: []}

# %% [markdown]
# # Score Imputation

# %% [markdown]
# ## Dictionary formation: {Topic: Score}

# %%
#new
topic_score_dict = {} # key: topic, value: occscore
topic_helper={i:[] for i in range(len(anchored_topic_model.get_topics()))}
#topic_helper: {topic_num:[(score,proba)...]}
for job_num in pairs_proba.keys():
    #job_num: index of each occ despcriction
    topic_prob=pairs_proba[job_num]
    #topic_prob: the list of topcis & prob that an occ belongs to
    #s: sum of weights (prob)
    occ=occ_original[job_num]
    #occ: each original occ description (without being cleaned of confusing words)
    score = list(df_occsc[df_occsc['Full Occupation']==occ]['OCCSCORE'])[0]
    #debug
    #score: occ score
    for pair in topic_prob:
        #pair: (topic,prob) 
        weight = pair[1]
        #weight: proba
        topic_helper[pair[0]].append((score,weight))

for topic in topic_helper.keys():
    lst = topic_helper[topic]
    #lst: [(score,proba)...] of a topic_num
    s=0
    for pair in lst:
        occ_score = 0
        s += pair[1]
    occ_score = 0
    for pair in lst:
        occ_score += pair[0] * (pair[1]/s)
    topic_score_dict[topic] = occ_score

# %%
topic_score_dict
# Out:
# {0: 24.535135135135093,
#  1: 28.909090909090903,
#  2: 27.03315210801016,
#  3: 24.66666666666666,
#  4: 22.86713488129816,
#  5: 0,
#  6: 33.00748826738642,
#  7: 24.3938547314314,
#  8: 34.190740835044046,
#  9: 22.491837210081172,
#  10: 11.79212183088381,
#  11: 30.214080849040446,
#  12: 0,
#  13: 12.041864438111295,
#  14: 21.5,
#  15: 19.630469565815964,
#  16: 23.040213394330653,
#  17: 27.420144607990828,
#  18: 25.475509895757824,
#  19: 21.73982020771473,
#  20: 36.198853140540194,
#  21: 27.0,
#  22: 13.882111286724651,
#  23: 0,
#  24: 25.93386750953296,
#  25: 28.958529602720564,
#  26: 31.444862482645238,
#  27: 26.619565217391262,
#  28: 0,
#  29: 23.0,
#  30: 9.633320731180573,
#  31: 26.759141957588298,
#  32: 23.736025778932397,
#  33: 42.0,
#  34: 0,
#  35: 31.0,
#  36: 0,
#  37: 18.837837837837835,
#  38: 20.394317003618113,
#  39: 51.7207657996545,
#  40: 42.0,
#  41: 39.0,
#  42: 21.500000000263043,
#  43: 0,
#  44: 0,
#  45: 27.0,
#  46: 33.00029869756232,
#  47: 19.070459766708996,
#  48: 38.0,
#  49: 26.236166835809065,
#  50: 27.658715829666235,
#  51: 25.4795102421778,
#  52: 42.0,
#  53: 25.0,
#  54: 25.362523101286648,
#  55: 23.0,
#  56: 30.153846153846146,
#  57: 23.630190544040552,
#  58: 0,
#  59: 0}

# %% [markdown]
# ## Load modified occ description
#
# ### Load Ancestry census data and calculate occ score¶

# %%
file = open('../../common_occupation_correction.pkl','rb')
mapping = pickle.load(file)
def mod_occ(occ):
    if occ in mapping.keys():
        return mapping[occ]
    else:
        return occ

df_ward = pd.read_csv('../../1910_New York_Manhattan Ward 9.csv')
df_ward['Occupation'] = df_ward['Occupation'].apply(lambda x : mod_occ(x))
df_ward['Full Occupation'] = df_ward['Industry'] + ' ' + df_ward['Occupation']

# %%
#drop all nans from full occupation
df_ward.drop(df_ward[df_ward['Full Occupation'].isna()].index, inplace = True)

# %%
# 32771 full occupations are nan values
print(df_ward['Full Occupation'].isna().sum())
# Out:
# 0

# %%
len(df_ward['Full Occupation'])
# Out:
# 32024

# %% [markdown]
# ### Compute occupation score of the given occupations¶

# %%
#new 
def plural(word):
    if word.endswith('y'):
        return word[:-1] + 'ies'
    elif word[-1] in 'sx' or word[-2:] in ['sh', 'ch']:
        return word + 'es'
    elif word.endswith('an'):
        return word[:-2] + 'en'
    else:
        return word + 's'
    
#debug
nan_count=topics_emp=0
not_in_dict_topicId=[]
empty_score=0
empty_score_occ_list=[]
not_in_dict_occ_with_dup=[]
#-------

def match_occ(occ):
     #debug
    global nan_count
    global topics_emp
    global not_in_dict_topicId
    global empty_score
    global not_in_dict_occ
    global empty_score_occ_list
    global not_in_dict_occ_with_dup
    #-------
    
    if type(occ) == float:
        
        #debug
        nan_count+=1
        #-------
        
        return 0
    else:
        
        vectorizer = CountVectorizer(       
                             stop_words='english',             
# remove stop words
                             lowercase=True,                   
# convert all words to lowercase
                             token_pattern='[a-zA-Z]',  
# num chars > 3
                             max_features=20000,
                             vocabulary=fixed_vocabulary,
                             binary=True         
# max number of uniq words    
                            )
        #vectorizer = CountVectorizer(stop_words='english', max_features=20000, vocabulary=fixed_vocabulary,binary=True)
        #debug
#         print(occ)
#         print()
        vectorizer = CountVectorizer(stop_words='english', max_features=20000, vocabulary=fixed_vocabulary,binary=True)
        doc_word1 = vectorizer.fit_transform([occ])
        doc_word1 = ss.csr_matrix(doc_word1)
        proba, mutual_info =anchored_topic_model.predict_proba(doc_word1)
        pairs=get_predict_proba(proba)
        #debug
#         print(pairs)
        #pairs: {0:[(topic_num,proba)...]}
        
        if pairs == {}:
            
            #debug
            topics_emp+=1
            #-------
            return 0
        else:
            score_list = []
            s = 0
            for pair in pairs[0]:
                #print(pairs[0])
                if pair[0] in topic_score_dict.keys():
                    score = topic_score_dict[pair[0]]
                    weight = np.e**pair[1]
                    s += weight
                    score_list.append((score,weight))       
            #debug
                else:
                    if pair[0] not in not_in_dict_topicId:
                        not_in_dict_topicId.append(pair[0])
                    not_in_dict_occ_with_dup.append(occ) 
            if score_list==[]: #when occ's score_list is completely empty (i.e. occ_score must be 0)
                empty_score+=1
                empty_score_occ_list.append(occ)
                
            #-------
            occ_score = 0
            for pair in score_list:
                occ_score += pair[0] * (pair[1]/s)
                
            return occ_score

# %%
df_ward['Occupation Score'] = df_ward['Full Occupation'].apply(lambda x : match_occ(x))

# %%
print(nan_count)
print(topics_emp)
print(not_in_dict_topicId)
print(empty_score)
print(empty_score_occ_list)
print(not_in_dict_occ_with_dup)
# Out:
# 0
# 0
# []
# 0
# []
# []

# %%
plt.hist(df_ward['Occupation Score'])
plt.title("OCC scores of test data")
# Out:
# Text(0.5, 1.0, 'OCC scores of test data')
# Error in callback <function flush_figures at 0x7f865b2f6160> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2103                             bbox_extra_artists=bbox_artists)
#    2104                     pad = kwargs.pop("pad_inches", None)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2383
#    2384         for a in artists:
# -> 2385             bbox = a.get_tightbbox(renderer)
#    2386             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2387                 bb.append(bbox)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4353             clip_extent = a._get_clipping_extent_bbox()
#    4354             if clip_extent is not None:
# -> 4355                 clip_extent = mtransforms.Bbox.intersection(clip_extent,
#    4356                     axbbox)
#    4357                 if np.all(clip_extent.extents == axbbox.extents):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in intersection(bbox1, bbox2)
#     713         None if they don't.
#     714         """
# --> 715         x0 = np.maximum(bbox1.xmin, bbox2.xmin)
#     716         x1 = np.minimum(bbox1.xmax, bbox2.xmax)
#     717         y0 = np.maximum(bbox1.ymin, bbox2.ymin)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in xmin(self)
#     347     def xmin(self):
#     348         """The left edge of the bounding box."""
# --> 349         return np.min(self.get_points()[:, 0])
#     350
#     351     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in get_points(self)
#    1020             # from the result, taking care to make the orientation the
#    1021             # same.
# -> 1022             points = self._transform.transform(
#    1023                 [[p[0, 0], p[0, 1]],
#    1024                  [p[1, 0], p[0, 1]],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in transform(self, values)
#    1403
#    1404         # Transform the values
# -> 1405         res = self.transform_affine(self.transform_non_affine(values))
#    1406
#    1407         # Convert the result back to the shape of the input values.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2363     def transform_affine(self, points):
#    2364         # docstring inherited
# -> 2365         return self.get_affine().transform(points)
#    2366
#    2367     def transform_non_affine(self, points):
#
# KeyboardInterrupt:

# %%
df_ward.to_csv('with_occ.csv')

# %% [markdown]
# ## Train Word2Vec model

# %%
def generate_labels(label):
    labels=[]
    for i in range(len(label)):
        no_value=True
        for j in range(topic_num):
            if label[i][j]==True:
                labels.append(j)
                no_value=False
                break
        if no_value:
            labels.append('nothing')
    return labels

labels=generate_labels(anchored_topic_model.labels)
label_for_use=[]
nothing_index=[]
for i in range(len(labels)):
    if labels[i]=='nothing':
        nothing_index.append(i)
    else:
        label_for_use.append(labels[i])

# %%
all_words=[]
for s in range(len(document_total)):
    if s not in nothing_index:
        temp=tokenize(document_total[s])
        all_words.append(temp)

# %%
import time
from gensim.models import Word2Vec
startTime = time.time()
word2vec_model = Word2Vec(all_words[:len(label_for_use)], size=200, iter=10, min_count=20)
usedTime = time.time() - startTime
print('形成word2vec模型共花费%.2f秒' %usedTime)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
word2vec_model.wv.most_similar('clerks')

# %%
word2vec_model.similarity('clerical','clerks')

# %%
import numpy as np

def get_contentVector(cutWords, word2vec_model):
    vector_list = [word2vec_model.wv[k] for k in cutWords if k in word2vec_model]
    contentVector = np.array(vector_list).mean(axis=0)
    return contentVector

# %%
import time

startTime = time.time()
contentVector_list = []
for i in range(len(all_words[:len(label_for_use)])):
    cutWords = all_words[i]
    content_vector=get_contentVector(cutWords, word2vec_model)
    contentVector_list.append(content_vector)
contentVector_list.pop(1875)
X = np.array(contentVector_list)
X.shape

# %%
from sklearn.preprocessing import LabelEncoder

labelEncoder = LabelEncoder()
y=label_for_use[:]
y.pop(1875)
y = labelEncoder.fit_transform(y)
print(X.shape, y.shape)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

logisticRegression_model = LogisticRegression()
logisticRegression_model.fit(X,y)

# %%
contentVector_predict = []
for i in range(len(all_words[len(label_for_use):])):
    cutWords = all_words[len(label_for_use):][i]
    content_vector=get_contentVector(cutWords, word2vec_model)
    contentVector_predict.append(content_vector)
X_predict = np.array(contentVector_predict)
results=logisticRegression_model.predict(X_predict)
word2vec_result=[]
for i in range(len(results)):
    word2vec_result.append([i,results[i]])

# %%
predict_same=0
for i in range(len(word2vec_result)):
    word2vec=word2vec_result[i]
    index=word2vec[0]
    for a,b in pairs:
        if a==index:
            if b==word2vec[1]:
                predict_same+=1
            print(occ_list[i],word2vec[1],b)

# %%
topic_score_dict_word2vec = {} # key: topic, value: occscore
topic_helper_word2vec={i:[] for i in range(topic_num)}
for a,b in word2vec_result:
    occ=occ_original[a]
    score = list(df_occsc[df_occsc['Full Occupation']==occ]['OCCSCORE'])[0]
    topic_helper_word2vec[b].append(score)

for topic in topic_helper_word2vec.keys():
    lst = topic_helper_word2vec[topic]
    if len(lst)!=0:
        occ_score=sum(lst)/len(lst)
        topic_score_dict_word2vec[topic] = occ_score
topic_score_dict_word2vec

# %%
import math
def word2vec_predict(occ):
    if type(occ) == float:
        return 0
    temp=tokenize(occ)
    contentVector_list = []
    content_vector=get_contentVector(temp, word2vec_model)
    if type(content_vector)==np.float64:
        return 0
    contentVector_list.append(content_vector)
    X_predict = np.array(contentVector_list)
    result=logisticRegression_model.predict(X_predict)
    if result[0] in topic_score_dict_word2vec.keys():
        occ_score=topic_score_dict_word2vec[result[0]]
        return occ_score
    else:
        return 0

df_ward['Occupation Score_Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_predict(x))
df_ward['Occupation Score_Word2Vec'] =  df_ward['Occupation Score_Word2Vec'].apply(lambda x:  round(x, 5))
df_ward

# %%
#plot histogram without the 0 values:
selection=(df_ward['Occupation Score_Word2Vec']!=0)
df_ward[selection]['Occupation Score_Word2Vec'].hist()
plt.title("old: subset=test,without 0 scores")

# %%
word2_score=list(df_ward['Occupation Score_Word2Vec'])
corex_score=list(df_ward['Occupation Score'])
difference=[]
for i in range(len(word2_score)):
    if (word2_score[i]!=0 and corex_score[i]!=0):
        difference.append(abs(word2_score[i]-corex_score[i]))
sum(difference)/len(difference)

# %%
#merge Corex with Word2Vec
for i in range(len(corex_score)):
    if corex_score[i]==0:
        if word2_score[i]!=0:
            corex_score[i]=word2_score[i]
df_ward['Occupation Score Merged']=corex_score
df_ward

# %%
#plot histogram without the 0 values:
selection=(df_ward['Occupation Score Merged']!=0)
df_ward[selection]['Occupation Score Merged'].hist()
plt.title("old: subset=test,without 0 scores")

# %% [markdown]
# ## Deal with Categories

# %%
import copy
occ_layer1=["manufacturing industries",
            "professional services",
            "trade & retail & business",
            "agriculture farmers",
            "government clerical officials",
            'domestic household',
            'transportation']

occ_sort=copy.deepcopy(document_total[len(documents_mod):])
occ_sort.sort()

# %%
occ_category={3:[range(11)],4:[range(11,23),range(287,304)],5:[range(23,60)],0:[range(60,249)],1:[range(249,287)],
              2:[range(304,384)],6:[range(384,436)]}
dic_occ={}# mapping occ to its bigger category in occ_layer1
for i in range(len(occ_sort)):
    for key,value in occ_category.items():
        for range_ in value:
            if i in range_:
                dic_occ[occ_sort[i]]=key

# %%
#try with word2vec
topic_category_word2vec={}
topic_category_helper_word2vec={i:[] for i in range(topic_num)}
for a,b in word2vec_result: # b is topic, a is occ index
    job_title=document_total[len(documents_mod):][a]
    job_category=dic_occ[job_title]
    topic_category_helper_word2vec[b].append(job_category)# without probability
for topic,lst in topic_category_helper_word2vec.items():
    if len(lst)!=0:
        total=len(lst)
        temp={}
        for a in range(len(occ_layer1)):
            temp[occ_layer1[a]]=lst.count(a)/total
        topic_category_word2vec[topic]=temp

# %%
#try with corex
topic_category_corex={}
topic_category_helper_corex={i:[] for i in range(topic_num)}
for job_num in pairs_proba.keys():
    topic_prob=pairs_proba[job_num]
    for pair in topic_prob:
        job_title=document_total[len(documents_mod):][job_num]
        job_category=dic_occ[job_title]
        weight = pair[1]
        topic_category_helper_corex[pair[0]].append((job_category,weight))

for topic in topic_category_helper_corex.keys():
    lst = topic_category_helper_corex[topic]
    if len(lst)!=0:
        total=0
        temp={}
        for a,b in lst: # a is category, b is proba
            total += b
        for i in range(len(occ_layer1)):
            count=0
            for a,b in lst:
                if i==a:
                    count+=b
            temp[occ_layer1[i]]=count/total
        topic_category_corex[topic]=temp

topic_category_corex

# %%
def word2vec_category(occ):
    if type(occ) == float:
        return 0
    temp=tokenize(occ)
    contentVector_list = []
    content_vector=get_contentVector(temp, word2vec_model)
    if type(content_vector)==np.float64:
        return 0
    contentVector_list.append(content_vector)
    X_predict = np.array(contentVector_list)
    result=logisticRegression_model.predict(X_predict)
    if result[0] in topic_category_word2vec.keys():
        category_proba=topic_category_word2vec[result[0]]
        sort_dict={k: v for k, v in sorted(category_proba.items(), key=lambda item: item[1],reverse=True)}
        category=list(sort_dict.keys())[0]
        return category
    else:
        return 0
df_ward['Occupation Category Word2Vec'] = df_ward['Full Occupation'].apply(lambda x : word2vec_category(x))

# %%
def corex_category(occ):
    if type(occ)!=float:
        vectorizer = CountVectorizer(stop_words='english', max_features=20000, vocabulary=fixed_vocabulary,binary=True)
        temp=[i.lower() for i in occ.split()]
        occ=" ".join(temp)
        doc_word1 = vectorizer.fit_transform([occ])
        doc_word1 = ss.csr_matrix(doc_word1)
        proba, mutual_info =anchored_topic_model.predict_proba(doc_word1)
        pairs=get_predict_proba(proba)
        if pairs == {}:
            return 0
        else:
            temp={i:0 for i in occ_layer1}
            #p=0
            for pair in pairs[0]:
                if pair[0] in topic_category_corex.keys():
                    proba_dict=topic_category_corex[pair[0]]
                    for a,b in proba_dict.items():
                        temp[a]+=pair[1]*b  
            sort_dict={k: v for k, v in sorted(temp.items(), key=lambda item: item[1],reverse=True)}
            category=list(sort_dict.keys())[0]
            return category
    else:
        return 0 
    
df_ward['Occupation Category Corex'] = df_ward['Full Occupation'].apply(lambda x : corex_category(x))

# %%
df_ward

# %%
list(df_ward['Occupation Category Corex']).count(0)
